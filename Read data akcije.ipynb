# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
dframe = pd.read_csv('mozgalo_gladbach_eintracht_csv.csv',sep=";")

# %%
dframe
# Out:
#             ID  gameID  actionStartTime  actionEndTime  actionID  \
# 0      6256994    6258             0.00           0.75       247
# 1      6256995    6258             0.75           1.31       247
# 2      6256996    6258             1.31           4.37       247
# 3      6256997    6258             4.37           7.12       247
# 4      6256998    6258             7.12           9.80       247
# 5      6256999    6258             9.80          11.38       247
# 6      6257000    6258            11.38          12.18       247
# 7      6257001    6258            12.18          15.11       247
# 8      6257002    6258            15.11          16.00       247
# 9      6257003    6258            16.00          16.92       247
# 10     6257004    6258            16.92          21.39       247
# 11     6257005    6258            21.39          23.45       247
# 12     6257006    6258            23.45          30.66       247
# ...

# %%
dframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70331 entries, 0 to 70330
# Data columns (total 35 columns):
# ID                  70331 non-null int64
# gameID              70331 non-null int64
# actionStartTime     70331 non-null float64
# actionEndTime       70331 non-null float64
# actionID            70331 non-null int64
# bindedActionID      70331 non-null int64
# actionOptionID      70331 non-null int64
# playerID            70331 non-null int64
# touchNumber         70331 non-null int64
# playerTeam          70331 non-null object
# actionPosX1         70331 non-null float64
# actionPosX2         70331 non-null float64
# actionPosY1         70331 non-null float64
# actionPosY2         70331 non-null float64
# targetPlayerID      70331 non-null int64
# goalZone            5201 non-null object
# lineColor           67099 non-null object
# lineDirection       67099 non-null object
# distance            70331 non-null float64
# refPositionX        70331 non-null float64
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#
gameIDs = pd.unique(dframe['gameID'])

# %%
gameIDs
# Out:
# array([6258, 6261, 6307, 6308, 6347, 6364, 6370, 6385, 6398, 6403, 6418,
#        6425, 6450, 6462, 6545, 6553, 6568, 6573, 6603, 6609, 6647, 6652,
#        6681, 6685, 6725, 6730, 6755, 6756, 6765, 6770])

# %%
gameIDs.size
# Out:
# 30

# %%
playerIDs = pd.unique(dframe['playerID'])

# %%
playerIDs
# Out:
# array([ 21913,   1992,   1892, 201366, 114354,  38433, 102537,  79430,
#         54482,  44079, 199745,  89661, 196633,  21022, 196661,   5335,
#         16520,  77888,   1802, 198668,  39442,   8570,  16894,  11500,
#         66692,  35785,  84297,  78198, 206309,  96310,  16271,  16491,
#         39479,  54769,   1818, 102647,   4610, 205485,  16087,  37911,
#         11043,  11341,  68597,  54689,   1819, 204427,  62146, 102895,
#        115078, 205986,  63129, 167977, 156709, 205180, 201539,  59326,
#         53084, 167694, 126631,  65256,  89662,   9354, 201879, 138853,
#         73607,  73299,   2025,  54180, 171186,  53937,  40700,  44428,
#         81305, 198337, 130205, 110657,  79410, 201853,  56958, 102533,
#         57720,   1897, 206102, 203641, 206101, 161221,  49374,  32926,
#        206094, 200739,  13690,  20356,  58666,   2183,  95786,  65127,
#         13122,  68515, 208487, 148852,  13635,  47041,   3153,  32947,
# ...

# %%
playerIDs.size
# Out:
# 347

# %%
grouped = dframe.groupby(['gameID'])

# %%
grouped.size()
# Out:
# gameID
# 6258    2199
# 6261    1882
# 6307    2352
# 6308    2300
# 6347    2293
# 6364    2505
# 6370    2298
# 6385    2711
# 6398    1923
# 6403    2748
# 6418    1993
# 6425    2399
# 6450    2349
# 6462    1903
# 6545    2581
# 6553    2485
# 6568    2488
# 6573    2172
# 6603    2307
# 6609    2289
# 6647    2331
# 6652    2500
# 6681    2507
# 6685    2656
# 6725    2548
# 6730    2309
# 6755    2304
# 6756    2112
# 6765    2443
# 6770    2444
# dtype: int64

# %%
grouped.describe()
# Out:
#                           ID  VideoActionEnd  VideoActionStart  actionEndTime  \
# gameID
# 6258   count     2199.000000               0                 0    2199.000000
#        mean   6260844.303774             NaN               NaN    2613.759059
#        std       2581.864043             NaN               NaN    1572.099327
#        min    6256994.000000             NaN               NaN       0.750000
#        25%    6258422.500000             NaN               NaN    1260.190000
#        50%    6260578.000000             NaN               NaN    2585.010000
#        75%    6263260.000000             NaN               NaN    4020.425000
#        max    6265371.000000             NaN               NaN    5583.590000
# 6261   count     1882.000000               0                 0    1882.000000
#        mean   6263977.023379             NaN               NaN    2686.916153
#        std       3715.072288             NaN               NaN    1577.719714
# ...

# %%
groupedpID = dframe.groupby(['gameID','playerID'])

# %%
groupedpID.describe()
# Out:
#                                    ID  VideoActionEnd  VideoActionStart  \
# gameID playerID
# 6258   1802     count       63.000000               0                 0
#                 mean   6260332.793651             NaN               NaN
#                 std       2488.593794             NaN               NaN
#                 min    6257082.000000             NaN               NaN
#                 25%    6257560.500000             NaN               NaN
#                 50%    6260082.000000             NaN               NaN
#                 75%    6262689.000000             NaN               NaN
#                 max    6265165.000000             NaN               NaN
#        1819     count       60.000000               0                 0
#                 mean   6263757.766667             NaN               NaN
#                 std        810.858017             NaN               NaN
#                 min    6262495.000000             NaN               NaN
# ...
