# %% [markdown]
# # Priprema podataka za SNA o kontra napadima

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import warnings
warnings.filterwarnings('ignore')

dfSve = pd.read_csv("mozgalo_gladbach_eintracht_akcije_spojeno.csv", sep = ',')

igraci = [8570, 196633, 5335, 21022, 16520, 199745, 77888, 39442, 1802, 1790, 1770, 22870, 40700, 196661, 212914, 203576, 
          206101, 67519, 143853, 57720, 12956, 44079, 7466, 205986, 102895, 201624, 214449, 206102]

dfEintrachtAkcije = dfSve[dfSve['playerID'].isin(igraci)]
dfEintrachtKontraNapadi = dfEintrachtAkcije[(dfEintrachtAkcije['actionID'] == 12) & 
                                            (dfEintrachtAkcije['actionOptionID'] == 354)]

dfEintrachtKontraNapadiClean = dfEintrachtKontraNapadi.drop(['ID', 'gameID', 'actionID',
                                            'bindedActionID', 'actionOptionID',
                                            'playerTeam', 'goalZone', 'refPositionX',
                                            'refPositionY', 'startPossTime', 'endPossTime', 'gameTimeSection',
                                            'playerPositionID', 'targetPositionID', 'awayTeamSide', 'action_duration',
                                            'domaci', 'gosti', 'domaciFormacija', 'gostiFormacija',
                                            'gameDate', 'gameTime', 'stadium', 'referee', 'stadium', 'climate',
                                            'luna', 'temperature', 'viewers', 'domaciID', 'gostiID', 'homeTeamFormacijaID',
                                            'awayTeamFormacijaID', 'Pogodaka_domaci', 'Score_domaci', 'Pogodaka_gosti',
                                            'Score_gosti', 'actionStartTime', 'actionEndTime', 'touchNumber',
                                            'ref_sector'], axis = 1)

dfEintrachtKontraNapadiClean.reset_index(drop=True, inplace=True)

dfEintrachtKontraNapadiClean1 = dfEintrachtKontraNapadiClean[dfEintrachtKontraNapadiClean['targetPlayerID'] != 0]
dfEintrachtKontraNapadiClean2 = dfEintrachtKontraNapadiClean1[(dfEintrachtKontraNapadiClean1['playerID'].isin(igraci)) & 
                                                  (dfEintrachtKontraNapadiClean1['targetPlayerID'].isin(igraci))]
dfEintrachtKontraNapadiClean3 = dfEintrachtKontraNapadiClean2[dfEintrachtKontraNapadiClean2['playerID'] != 
                                                  dfEintrachtKontraNapadiClean2['targetPlayerID']]

dfEP = pd.read_csv("eintrachtP.csv", sep=',')

dfEintrachtIgraci = pd.merge(dfEintrachtKontraNapadiClean3, dfEP, left_on='playerID', right_on='playerID', how='left')
dfEintrachtIgraci2 = pd.merge(dfEintrachtIgraci, dfEP, left_on='targetPlayerID', right_on='playerID', how='left')
dfEintrachtIgraci3 = dfEintrachtIgraci2.drop('playerID_y', axis=1)
dfEintrachtIgraci4 = dfEintrachtIgraci3.rename(columns={'name_x':'playerName', 'name_y':'targetName', 'playerID_x':'playerID'})
dfEintrachtIgraci5 = dfEintrachtIgraci4.drop(['distance'], axis=1)
dfEintrachtIgraci5['Weight'] = dfEintrachtIgraci5.groupby('playerID')['targetPlayerID'].transform(pd.Series.value_counts)
dfEintrachtIgraci5 = dfEintrachtIgraci5.drop_duplicates()
dfEintrachtIgraci5.to_csv("Eintracht_sna_kontra_napadi.csv", sep=',', index=False)
dfEintrachtIgraci5
# Out:
#     playerID playerPositionIDN actionIDNaziv  bindedActionIDN  \
# 0     199745               LCM  KONTRA NAPAD                0
# 1       1802               CAM  KONTRA NAPAD                0
# 2      16520                RW  KONTRA NAPAD                0
# 3      40700               LCM  KONTRA NAPAD                0
# 4      44079               LDM  KONTRA NAPAD                0
# 5      44079               LDM  KONTRA NAPAD  TOCNO DODAVANJE
# 6       1802               LCM  KONTRA NAPAD                0
# 7      77888                ST  KONTRA NAPAD                0
# 8     199745               RCM  KONTRA NAPAD                0
# 9       1802               CAM  KONTRA NAPAD                0
# 10      1790               RCB  KONTRA NAPAD                0
# 11     12956                LW  KONTRA NAPAD                0
# 12     22870                ST  KONTRA NAPAD                0
# 13    212914                RB  KONTRA NAPAD                0
# 14     39442               RCB  KONTRA NAPAD                0
# 15     22870               CAM  KONTRA NAPAD                0
# 16    199745               LCM  KONTRA NAPAD                0
# 17      1770                LW  KONTRA NAPAD                0
#
#             actionOptionIDN  targetPlayerID targetPositionIDN  actionPosX1  \
# 0   POCETAK KONTRA NAPADA 1          102895                ST          865
# 1   POCETAK KONTRA NAPADA 1           40700               RCM          700
# 2   POCETAK KONTRA NAPADA 1           77888                ST         1091
# 3   POCETAK KONTRA NAPADA 1          203576                LW         1013
# 4   POCETAK KONTRA NAPADA 1           77888                ST          908
# 5   POCETAK KONTRA NAPADA 1          199745               CAM          928
# 6   POCETAK KONTRA NAPADA 1           12956                LB         1031
# 7   POCETAK KONTRA NAPADA 1           67519                LW          591
# 8   POCETAK KONTRA NAPADA 1           77888                ST          467
# 9   POCETAK KONTRA NAPADA 1           16520                RW          458
# 10  POCETAK KONTRA NAPADA 1           77888                ST          194
# 11  POCETAK KONTRA NAPADA 1           77888                ST          401
# 12  POCETAK KONTRA NAPADA 1           16520                RW          619
# 13  POCETAK KONTRA NAPADA 1           77888                LW          779
# 14  POCETAK KONTRA NAPADA 1           22870               CAM          332
# 15  POCETAK KONTRA NAPADA 1           77888                LW          432
# 16  POCETAK KONTRA NAPADA 1           22870               CAM          746
# 17  POCETAK KONTRA NAPADA 1           77888                ST          578
#
#     actionPosX2  actionPosY1  actionPosY2  poss_duration  start_sector  \
# 0           728       302.32       171.32           4.01             7
# 1           693       301.32       440.32           0.00             6
# 2           963        90.32       111.32           1.23             4
# 3          1021       579.32       644.32           0.69            11
# 4           632       193.32       355.32           0.19             3
# 5           864       347.32       397.32           0.17             7
# 6          1146       363.32       314.32           2.63             7
# 7           594       223.32       358.32           0.75             2
# 8           948       628.32       644.32           3.32            10
# 9           449       409.32       686.32           0.15             6
# 10          903       458.32       109.32           0.15             9
# 11          668       309.32       204.32           0.16             6
# 12          625       581.32       624.32           0.35            10
# 13          956       594.32       466.32           3.04            11
# 14          397       420.32       326.32           1.66             5
# 15          684       314.32       129.32           0.13             6
# 16          869       532.32       401.32           1.34            11
# 17          508       566.32       392.32           0.25            10
#
#     end_sector    playerName     targetName  Weight
# 0            3   M. Stendera  L. Castaignos       1
# 1            6      A. Meier   S. Medojevic       1
# 2            3     S. Aigner   H. Seferovic       1
# 3           11  S. Medojevic   M. Gacinovic       1
# 4            6   S. Reinartz   H. Seferovic       1
# 5            7   S. Reinartz    M. Stendera       1
# 6            8      A. Meier      C. Djakpa       1
# 7            6  H. Seferovic      V. Kadlec       1
# 8           11   M. Stendera   H. Seferovic       1
# 9           14      A. Meier      S. Aigner       1
# 10           3       M. Russ   H. Seferovic       1
# 11           2     C. Djakpa   H. Seferovic       1
# 12          10     M. Fabian      S. Aigner       1
# 13          11    Y. Regasel   H. Seferovic       1
# 14           6   C. Zambrano      M. Fabian       1
# 15           2     M. Fabian   H. Seferovic       1
# 16           7   M. Stendera      M. Fabian       1
# 17           6     S. Huszti   H. Seferovic       1

# %% [markdown]
# # Priprema čvorova

# %%
dfNodes = dfEintrachtIgraci5[['playerID', 'playerName']]
dfNodesUnique = dfNodes.drop_duplicates()
dfNodesUniqueRenamed = dfNodesUnique.rename(columns={'playerID':'ID', 'playerName':'Label'})
dfNodesUniqueRenamed.to_csv("Eintracht_sna_kontre_nodes.csv", sep=',', index=False)

# %% [markdown]
# # Priprema bridova

# %%
dfEintrachtIgraci5['Label'] = dfEintrachtIgraci5['start_sector'].map(str) + " " + dfEintrachtIgraci5['end_sector'].map(str)
dfEdges = dfEintrachtIgraci5.rename(columns={'playerID':'Source', 'targetPlayerID':'Target', 'weight':'Weight'})
dfEdges.to_csv("Eintracht_sna_kontre_edges.csv", sep=',', index=False)

# %% [markdown]
# # Priprema podataka o udarcima (izvan okvira)

# %%
dfEintrachtAtrUdarci = dfEintrachtAkcije[(dfEintrachtAkcije['actionID'] == 30) & 
                                            (dfEintrachtAkcije['bindedActionID'] == 262)]
dfEintrachtAtrUdarciClean = dfEintrachtAtrUdarci.drop(['ID','gameID', 'actionID',
                                            'bindedActionID', 'actionOptionID',
                                            'playerTeam', 'refPositionX',
                                            'refPositionY', 'startPossTime', 'endPossTime', 'gameTimeSection',
                                            'playerPositionID', 'targetPositionID', 'awayTeamSide', 'action_duration',
                                            'domaci', 'gosti', 'domaciFormacija', 'gostiFormacija',
                                            'gameDate', 'gameTime', 'stadium', 'referee', 'stadium', 'climate',
                                            'luna', 'temperature', 'viewers', 'domaciID', 'gostiID', 'homeTeamFormacijaID',
                                            'awayTeamFormacijaID', 'Pogodaka_domaci', 'Score_domaci', 'Pogodaka_gosti',
                                            'Score_gosti', 'actionStartTime', 'actionEndTime', 'touchNumber',
                                            'ref_sector', 'poss_duration'], axis = 1)

dfEintrachtAtrUdarciClean.reset_index(drop=True, inplace=True)

dfEP = pd.read_csv("eintrachtP.csv", sep=',')

dfEintrachtu = pd.merge(dfEintrachtAtrUdarciClean, dfEP, left_on='playerID', right_on='playerID', how='left')
dfEintrachtIgraciu1 = pd.merge(dfEintrachtu, dfEP, left_on='targetPlayerID', right_on='playerID', how='left')
dfEintrachtIgraciu2 = dfEintrachtIgraciu1.drop(['playerID_y', 'name_y'], axis=1)
dfEintrachtIgraciu3 = dfEintrachtIgraciu2.rename(columns={'name_x':'playerName', 'name_y':'targetName', 'playerID_x':'playerID'})
dfEintrachtIgraciu3.index += 1
dfEintrachtIgraciu3.to_csv("Eintracht_sna_udarci_izvan_okvira.csv", sep=',', index=False)
dfEintrachtIgraciu3
# Out:
#      playerID playerPositionIDN actionIDNaziv      bindedActionIDN  \
# 1        1802               CAM        UDARAC  UDARAC IZVAN OKVIRA
# 2        1802               CAM        UDARAC  UDARAC IZVAN OKVIRA
# 3        1802               CAM        UDARAC  UDARAC IZVAN OKVIRA
# 4      196661                LW        UDARAC  UDARAC IZVAN OKVIRA
# 5      196661                LW        UDARAC  UDARAC IZVAN OKVIRA
# 6      196661                LW        UDARAC  UDARAC IZVAN OKVIRA
# 7       77888                ST        UDARAC  UDARAC IZVAN OKVIRA
# 8       77888                ST        UDARAC  UDARAC IZVAN OKVIRA
# 9       77888                ST        UDARAC  UDARAC IZVAN OKVIRA
# 10       1802               CAM        UDARAC  UDARAC IZVAN OKVIRA
# 11       1802               CAM        UDARAC  UDARAC IZVAN OKVIRA
# 12       1802               CAM        UDARAC  UDARAC IZVAN OKVIRA
# 13      40700               RCM        UDARAC  UDARAC IZVAN OKVIRA
# 14      40700               RCM        UDARAC  UDARAC IZVAN OKVIRA
# 15      16520                RW        UDARAC  UDARAC IZVAN OKVIRA
# 16      16520                RW        UDARAC  UDARAC IZVAN OKVIRA
# 17      16520                RW        UDARAC  UDARAC IZVAN OKVIRA
# 18      16520                RW        UDARAC  UDARAC IZVAN OKVIRA
# 19       1802               CAM        UDARAC  UDARAC IZVAN OKVIRA
# 20       1802               CAM        UDARAC  UDARAC IZVAN OKVIRA
# 21       1802               CAM        UDARAC  UDARAC IZVAN OKVIRA
# 22       1802               CAM        UDARAC  UDARAC IZVAN OKVIRA
# 23      16520                RW        UDARAC  UDARAC IZVAN OKVIRA
# 24      16520                RW        UDARAC  UDARAC IZVAN OKVIRA
# 25      77888                ST        UDARAC  UDARAC IZVAN OKVIRA
# 26      77888                ST        UDARAC  UDARAC IZVAN OKVIRA
# 27     196661               RCM        UDARAC  UDARAC IZVAN OKVIRA
# 28     196661               RCM        UDARAC  UDARAC IZVAN OKVIRA
# 29     196661               RCM        UDARAC  UDARAC IZVAN OKVIRA
# 30     196661               RCM        UDARAC  UDARAC IZVAN OKVIRA
# ..        ...               ...           ...                  ...
# 171     77888               RCF        UDARAC  UDARAC IZVAN OKVIRA
# 172    199745               LCM        UDARAC  UDARAC IZVAN OKVIRA
# 173    199745               LCM        UDARAC  UDARAC IZVAN OKVIRA
# 174    199745               LCM        UDARAC  UDARAC IZVAN OKVIRA
# 175    206101               LCM        UDARAC  UDARAC IZVAN OKVIRA
# 176    206101               LCM        UDARAC  UDARAC IZVAN OKVIRA
# 177     77888               RCF        UDARAC  UDARAC IZVAN OKVIRA
# 178     77888               RCF        UDARAC  UDARAC IZVAN OKVIRA
# 179     77888               RCF        UDARAC  UDARAC IZVAN OKVIRA
# 180     39442               RCB        UDARAC  UDARAC IZVAN OKVIRA
# 181     39442               RCB        UDARAC  UDARAC IZVAN OKVIRA
# 182     77888               RCF        UDARAC  UDARAC IZVAN OKVIRA
# 183     77888               RCF        UDARAC  UDARAC IZVAN OKVIRA
# 184    206101               LCM        UDARAC  UDARAC IZVAN OKVIRA
# 185    206101               LCM        UDARAC  UDARAC IZVAN OKVIRA
# 186    206101               LCM        UDARAC  UDARAC IZVAN OKVIRA
# 187     22870               LCF        UDARAC  UDARAC IZVAN OKVIRA
# 188     22870               LCF        UDARAC  UDARAC IZVAN OKVIRA
# 189     22870               LCF        UDARAC  UDARAC IZVAN OKVIRA
# 190    212914               RWB        UDARAC  UDARAC IZVAN OKVIRA
# 191    212914               RWB        UDARAC  UDARAC IZVAN OKVIRA
# 192    212914               RWB        UDARAC  UDARAC IZVAN OKVIRA
# 193    212914               RWB        UDARAC  UDARAC IZVAN OKVIRA
# 194     77888               RCF        UDARAC  UDARAC IZVAN OKVIRA
# 195     77888               RCF        UDARAC  UDARAC IZVAN OKVIRA
# 196     77888               RCF        UDARAC  UDARAC IZVAN OKVIRA
# 197     77888               RCF        UDARAC  UDARAC IZVAN OKVIRA
# 198     77888               RCF        UDARAC  UDARAC IZVAN OKVIRA
# 199     21022               LCB        UDARAC  UDARAC IZVAN OKVIRA
# 200     21022               LCB        UDARAC  UDARAC IZVAN OKVIRA
#
#     actionOptionIDN  targetPlayerID targetPositionIDN  actionPosX1  \
# 1            GLAVOM               0                 0         1127
# 2               LOS               0                 0         1127
# 3          PO ZRAKU               0                 0         1127
# 4        DESNA NOGA               0                 0           84
# 5               LOS               0                 0           84
# 6          PO ZRAKU               0                 0           84
# 7            GLAVOM               0                 0          118
# 8          PO ZRAKU               0                 0          118
# 9               LOS               0                 0          118
# 10         PO ZRAKU               0                 0          150
# 11           GLAVOM               0                 0          150
# 12              LOS               0                 0          150
# 13           GLAVOM               0                 0          123
# 14         PO ZRAKU               0                 0          123
# 15       DESNA NOGA               0                 0         1119
# 16         PO ZRAKU               0                 0         1119
# 17      LIJEVA NOGA               0                 0         1153
# 18         PO ZRAKU               0                 0         1153
# 19        PO ZEMLJI               0                 0         1035
# 20              LOS               0                 0         1035
# 21       DESNA NOGA               0                 0         1035
# 22             ZONA               0                 0         1035
# 23        PO ZEMLJI               0                 0         1130
# 24       DESNA NOGA               0                 0         1130
# 25         PO ZRAKU               0                 0         1168
# 26           GLAVOM               0                 0         1168
# 27         PO ZRAKU               0                 0          362
# 28              LOS               0                 0          362
# 29      LIJEVA NOGA               0                 0          362
# 30             ZONA               0                 0          362
# ..              ...             ...               ...          ...
# 171            ZONA               0                 0          331
# 172        PO ZRAKU               0                 0          233
# 173      DESNA NOGA               0                 0          233
# 174             LOS               0                 0          233
# 175          GLAVOM               0                 0         1236
# 176        PO ZRAKU               0                 0         1236
# 177       PO ZEMLJI               0                 0         1140
# 178      DESNA NOGA               0                 0         1140
# 179             LOS               0                 0         1140
# 180        PO ZRAKU               0                 0         1224
# 181          GLAVOM               0                 0         1224
# 182          GLAVOM               0                 0         1157
# 183             LOS               0                 0         1157
# 184        PO ZRAKU               0                 0         1166
# 185             LOS               0                 0         1166
# 186     LIJEVA NOGA               0                 0         1166
# 187            ZONA               0                 0         1036
# 188      DESNA NOGA               0                 0         1036
# 189       PO ZEMLJI               0                 0         1036
# 190             LOS               0                 0         1226
# 191        PO ZRAKU               0                 0         1226
# 192       IZ VOLEJA               0                 0         1226
# 193      DESNA NOGA               0                 0         1226
# 194        PO ZRAKU               0                 0         1215
# 195          GLAVOM               0                 0         1215
# 196       PO ZEMLJI               0                 0         1184
# 197             LOS               0                 0         1184
# 198     LIJEVA NOGA               0                 0         1184
# 199        PO ZRAKU               0                 0         1210
# 200          GLAVOM               0                 0         1210
#
#      actionPosX2  actionPosY1  actionPosY2 goalZone  distance  start_sector  \
# 1           1276       449.32       393.32  Label65     12.89             8
# 2           1276       449.32       393.32  Label65     12.89             8
# 3           1276       449.32       393.32  Label65     12.89             8
# 4             64       502.32       441.32  Label66      5.46             9
# 5             64       502.32       441.32  Label66      5.46             9
# 6             64       502.32       441.32  Label66      5.46             9
# 7             71       356.32       381.32  Label66      4.34             5
# 8             71       356.32       381.32  Label66      4.34             5
# 9             71       356.32       381.32  Label66      4.34             5
# 10           145       387.32       411.32  Label64      2.09             5
# 11           145       387.32       411.32  Label64      2.09             5
# 12           145       387.32       411.32  Label64      2.09             5
# 13            77       489.32       491.32  Label68      3.70             9
# 14            77       489.32       491.32  Label68      3.70             9
# 15          1262       552.32       492.32  Label51     12.58            12
# 16          1262       552.32       492.32  Label51     12.58            12
# 17          1256       433.32       418.32  Label65      8.37             8
# 18          1256       433.32       418.32  Label65      8.37             8
# 19          1217       401.32       325.32  Label60     16.01             7
# 20          1217       401.32       325.32  Label60     16.01             7
# 21          1217       401.32       325.32  Label60     16.01             7
# 22          1217       401.32       325.32  Label60     16.01             7
# 23          1250       562.32       381.32  Label57     18.26            12
# 24          1250       562.32       381.32  Label57     18.26            12
# 25          1244       478.32       369.32  Label52     11.16            12
# 26          1244       478.32       369.32  Label52     11.16            12
# 27           127       182.32       452.32  Label61     29.86             2
# 28           127       182.32       452.32  Label61     29.86             2
# 29           127       182.32       452.32  Label61     29.86             2
# 30           127       182.32       452.32  Label61     29.86             2
# ..           ...          ...          ...      ...       ...           ...
# 171           63       528.32       489.32  Label53     21.79             9
# 172          217       604.32        60.32  Label50     46.64             9
# 173          217       604.32        60.32  Label50     46.64             9
# 174          217       604.32        60.32  Label50     46.64             9
# 175         1289       356.32       476.32  Label93     11.13             8
# 176         1289       356.32       476.32  Label93     11.13             8
# 177         1285       471.32       553.32  Label98     13.60            12
# 178         1285       471.32       553.32  Label98     13.60            12
# 179         1285       471.32       553.32  Label98     13.60            12
# 180         1285       422.32       402.32  Label65      5.19             8
# 181         1285       422.32       402.32  Label65      5.19             8
# 182         1280       440.32       498.32  Label97     11.06             8
# 183         1280       440.32       498.32  Label97     11.06             8
# 184         1275       481.32       429.32  Label65      9.82            12
# 185         1275       481.32       429.32  Label65      9.82            12
# 186         1275       481.32       429.32  Label65      9.82            12
# 187         1288       228.32       364.32  Label57     23.36             7
# 188         1288       228.32       364.32  Label57     23.36             7
# 189         1288       228.32       364.32  Label57     23.36             7
# 190         1249       553.32       759.32  Label50     17.75            12
# 191         1249       553.32       759.32  Label50     17.75            12
# 192         1249       553.32       759.32  Label50     17.75            12
# 193         1249       553.32       759.32  Label50     17.75            12
# 194         1282       420.32       429.32  Label66      5.43             8
# 195         1282       420.32       429.32  Label66      5.43             8
# 196         1285       278.32       347.32  Label53     10.04             8
# 197         1285       278.32       347.32  Label53     10.04             8
# 198         1285       278.32       347.32  Label53     10.04             8
# 199         1290       452.32       457.32  Label66      6.44            12
# 200         1290       452.32       457.32  Label66      6.44            12
#
#      end_sector      playerName
# 1             8        A. Meier
# 2             8        A. Meier
# 3             8        A. Meier
# 4             5    A. Ignjovski
# 5             5    A. Ignjovski
# 6             5    A. Ignjovski
# 7             5    H. Seferovic
# 8             5    H. Seferovic
# 9             5    H. Seferovic
# 10            5        A. Meier
# 11            5        A. Meier
# 12            5        A. Meier
# 13            9    S. Medojevic
# 14            9    S. Medojevic
# 15           12       S. Aigner
# 16           12       S. Aigner
# 17            8       S. Aigner
# 18            8       S. Aigner
# 19            8        A. Meier
# 20            8        A. Meier
# 21            8        A. Meier
# 22            8        A. Meier
# 23            8       S. Aigner
# 24            8       S. Aigner
# 25            8    H. Seferovic
# 26            8    H. Seferovic
# 27            9    A. Ignjovski
# 28            9    A. Ignjovski
# 29            9    A. Ignjovski
# 30            9    A. Ignjovski
# ..          ...             ...
# 171           9    H. Seferovic
# 172           1     M. Stendera
# 173           1     M. Stendera
# 174           1     M. Stendera
# 175          12  G. Waldschmidt
# 176          12  G. Waldschmidt
# 177          12    H. Seferovic
# 178          12    H. Seferovic
# 179          12    H. Seferovic
# 180           8     C. Zambrano
# 181           8     C. Zambrano
# 182          12    H. Seferovic
# 183          12    H. Seferovic
# 184           8  G. Waldschmidt
# 185           8  G. Waldschmidt
# 186           8  G. Waldschmidt
# 187           8       M. Fabian
# 188           8       M. Fabian
# 189           8       M. Fabian
# 190          16      Y. Regasel
# 191          16      Y. Regasel
# 192          16      Y. Regasel
# 193          16      Y. Regasel
# 194           8    H. Seferovic
# 195           8    H. Seferovic
# 196           8    H. Seferovic
# 197           8    H. Seferovic
# 198           8    H. Seferovic
# 199          12      L. Abraham
# 200          12      L. Abraham
#
# [200 rows x 16 columns]

# %% [markdown]
# # Priprema čvorova za udarce izvan okvira

# %%
dfsource = dfEintrachtIgraciu3['playerName']
dftarget = dfEintrachtIgraciu3['goalZone']

frames = [dfsource, dftarget]

dfNodesu = pd.concat(frames)
dfNodesuClean = dfNodesu.drop_duplicates()
dfNodesuClean.reset_index(drop=True, inplace=True)
dfNodesuClean.index += 1
dfNodesuClean.to_csv("Eintracht_sna_udarci_izvan_okvira_nodes.csv", sep=',', index=True)

# %% [markdown]
# # Priprema bridova za udarce izvan okvira

# %%
dfEintrachtUdarci = pd.read_csv("Eintracht_sna_udarci_izvan_okvira.csv", sep=',')
dfEintrachtNodesU = pd.read_csv("Eintracht_sna_udarci_izvan_okvira_nodes.csv", sep=',', names=['ID', 'Label'])

for indexU, itemU in dfEintrachtUdarci.iterrows():
    for indexN, itemN in dfEintrachtNodesU.iterrows():
        if(itemU['playerName'] == itemN['Label']):
            ID = int(itemN['ID'])
            dfEintrachtUdarci.set_value(indexU, 'Source', ID)
            
for indexU, itemU in dfEintrachtUdarci.iterrows():
    for indexN, itemN in dfEintrachtNodesU.iterrows():
        if(itemU['goalZone'] == itemN['Label']):
            ID = int(itemN['ID'])
            dfEintrachtUdarci.set_value(indexU, 'Target', ID)

dfEintrachtUdarci['Label'] = dfEintrachtUdarci['distance'].map(str) + " " + dfEintrachtUdarci['start_sector'].map(str)
dfEintrachtUdarci.drop(['targetPlayerID', 'targetPositionIDN', 'distance'], axis=1, inplace=True)
dfEintrachtUdarci.to_csv("Eintracht_sna_udarci_izvan_okvira_edges.csv", sep=',', index=False)
dfEintrachtUdarci
# Out:
#      playerID playerPositionIDN actionIDNaziv      bindedActionIDN  \
# 0        1802               CAM        UDARAC  UDARAC IZVAN OKVIRA
# 1        1802               CAM        UDARAC  UDARAC IZVAN OKVIRA
# 2        1802               CAM        UDARAC  UDARAC IZVAN OKVIRA
# 3      196661                LW        UDARAC  UDARAC IZVAN OKVIRA
# 4      196661                LW        UDARAC  UDARAC IZVAN OKVIRA
# 5      196661                LW        UDARAC  UDARAC IZVAN OKVIRA
# 6       77888                ST        UDARAC  UDARAC IZVAN OKVIRA
# 7       77888                ST        UDARAC  UDARAC IZVAN OKVIRA
# 8       77888                ST        UDARAC  UDARAC IZVAN OKVIRA
# 9        1802               CAM        UDARAC  UDARAC IZVAN OKVIRA
# 10       1802               CAM        UDARAC  UDARAC IZVAN OKVIRA
# 11       1802               CAM        UDARAC  UDARAC IZVAN OKVIRA
# 12      40700               RCM        UDARAC  UDARAC IZVAN OKVIRA
# 13      40700               RCM        UDARAC  UDARAC IZVAN OKVIRA
# 14      16520                RW        UDARAC  UDARAC IZVAN OKVIRA
# 15      16520                RW        UDARAC  UDARAC IZVAN OKVIRA
# 16      16520                RW        UDARAC  UDARAC IZVAN OKVIRA
# 17      16520                RW        UDARAC  UDARAC IZVAN OKVIRA
# 18       1802               CAM        UDARAC  UDARAC IZVAN OKVIRA
# 19       1802               CAM        UDARAC  UDARAC IZVAN OKVIRA
# 20       1802               CAM        UDARAC  UDARAC IZVAN OKVIRA
# 21       1802               CAM        UDARAC  UDARAC IZVAN OKVIRA
# 22      16520                RW        UDARAC  UDARAC IZVAN OKVIRA
# 23      16520                RW        UDARAC  UDARAC IZVAN OKVIRA
# 24      77888                ST        UDARAC  UDARAC IZVAN OKVIRA
# 25      77888                ST        UDARAC  UDARAC IZVAN OKVIRA
# 26     196661               RCM        UDARAC  UDARAC IZVAN OKVIRA
# 27     196661               RCM        UDARAC  UDARAC IZVAN OKVIRA
# 28     196661               RCM        UDARAC  UDARAC IZVAN OKVIRA
# 29     196661               RCM        UDARAC  UDARAC IZVAN OKVIRA
# ..        ...               ...           ...                  ...
# 170     77888               RCF        UDARAC  UDARAC IZVAN OKVIRA
# 171    199745               LCM        UDARAC  UDARAC IZVAN OKVIRA
# 172    199745               LCM        UDARAC  UDARAC IZVAN OKVIRA
# 173    199745               LCM        UDARAC  UDARAC IZVAN OKVIRA
# 174    206101               LCM        UDARAC  UDARAC IZVAN OKVIRA
# 175    206101               LCM        UDARAC  UDARAC IZVAN OKVIRA
# 176     77888               RCF        UDARAC  UDARAC IZVAN OKVIRA
# 177     77888               RCF        UDARAC  UDARAC IZVAN OKVIRA
# 178     77888               RCF        UDARAC  UDARAC IZVAN OKVIRA
# 179     39442               RCB        UDARAC  UDARAC IZVAN OKVIRA
# 180     39442               RCB        UDARAC  UDARAC IZVAN OKVIRA
# 181     77888               RCF        UDARAC  UDARAC IZVAN OKVIRA
# 182     77888               RCF        UDARAC  UDARAC IZVAN OKVIRA
# 183    206101               LCM        UDARAC  UDARAC IZVAN OKVIRA
# 184    206101               LCM        UDARAC  UDARAC IZVAN OKVIRA
# 185    206101               LCM        UDARAC  UDARAC IZVAN OKVIRA
# 186     22870               LCF        UDARAC  UDARAC IZVAN OKVIRA
# 187     22870               LCF        UDARAC  UDARAC IZVAN OKVIRA
# 188     22870               LCF        UDARAC  UDARAC IZVAN OKVIRA
# 189    212914               RWB        UDARAC  UDARAC IZVAN OKVIRA
# 190    212914               RWB        UDARAC  UDARAC IZVAN OKVIRA
# 191    212914               RWB        UDARAC  UDARAC IZVAN OKVIRA
# 192    212914               RWB        UDARAC  UDARAC IZVAN OKVIRA
# 193     77888               RCF        UDARAC  UDARAC IZVAN OKVIRA
# 194     77888               RCF        UDARAC  UDARAC IZVAN OKVIRA
# 195     77888               RCF        UDARAC  UDARAC IZVAN OKVIRA
# 196     77888               RCF        UDARAC  UDARAC IZVAN OKVIRA
# 197     77888               RCF        UDARAC  UDARAC IZVAN OKVIRA
# 198     21022               LCB        UDARAC  UDARAC IZVAN OKVIRA
# 199     21022               LCB        UDARAC  UDARAC IZVAN OKVIRA
#
#     actionOptionIDN goalZone  start_sector  end_sector      playerName  \
# 0            GLAVOM  Label65             8           8        A. Meier
# 1               LOS  Label65             8           8        A. Meier
# 2          PO ZRAKU  Label65             8           8        A. Meier
# 3        DESNA NOGA  Label66             9           5    A. Ignjovski
# 4               LOS  Label66             9           5    A. Ignjovski
# 5          PO ZRAKU  Label66             9           5    A. Ignjovski
# 6            GLAVOM  Label66             5           5    H. Seferovic
# 7          PO ZRAKU  Label66             5           5    H. Seferovic
# 8               LOS  Label66             5           5    H. Seferovic
# 9          PO ZRAKU  Label64             5           5        A. Meier
# 10           GLAVOM  Label64             5           5        A. Meier
# 11              LOS  Label64             5           5        A. Meier
# 12           GLAVOM  Label68             9           9    S. Medojevic
# 13         PO ZRAKU  Label68             9           9    S. Medojevic
# 14       DESNA NOGA  Label51            12          12       S. Aigner
# 15         PO ZRAKU  Label51            12          12       S. Aigner
# 16      LIJEVA NOGA  Label65             8           8       S. Aigner
# 17         PO ZRAKU  Label65             8           8       S. Aigner
# 18        PO ZEMLJI  Label60             7           8        A. Meier
# 19              LOS  Label60             7           8        A. Meier
# 20       DESNA NOGA  Label60             7           8        A. Meier
# 21             ZONA  Label60             7           8        A. Meier
# 22        PO ZEMLJI  Label57            12           8       S. Aigner
# 23       DESNA NOGA  Label57            12           8       S. Aigner
# 24         PO ZRAKU  Label52            12           8    H. Seferovic
# 25           GLAVOM  Label52            12           8    H. Seferovic
# 26         PO ZRAKU  Label61             2           9    A. Ignjovski
# 27              LOS  Label61             2           9    A. Ignjovski
# 28      LIJEVA NOGA  Label61             2           9    A. Ignjovski
# 29             ZONA  Label61             2           9    A. Ignjovski
# ..              ...      ...           ...         ...             ...
# 170            ZONA  Label53             9           9    H. Seferovic
# 171        PO ZRAKU  Label50             9           1     M. Stendera
# 172      DESNA NOGA  Label50             9           1     M. Stendera
# 173             LOS  Label50             9           1     M. Stendera
# 174          GLAVOM  Label93             8          12  G. Waldschmidt
# 175        PO ZRAKU  Label93             8          12  G. Waldschmidt
# 176       PO ZEMLJI  Label98            12          12    H. Seferovic
# 177      DESNA NOGA  Label98            12          12    H. Seferovic
# 178             LOS  Label98            12          12    H. Seferovic
# 179        PO ZRAKU  Label65             8           8     C. Zambrano
# 180          GLAVOM  Label65             8           8     C. Zambrano
# 181          GLAVOM  Label97             8          12    H. Seferovic
# 182             LOS  Label97             8          12    H. Seferovic
# 183        PO ZRAKU  Label65            12           8  G. Waldschmidt
# 184             LOS  Label65            12           8  G. Waldschmidt
# 185     LIJEVA NOGA  Label65            12           8  G. Waldschmidt
# 186            ZONA  Label57             7           8       M. Fabian
# 187      DESNA NOGA  Label57             7           8       M. Fabian
# 188       PO ZEMLJI  Label57             7           8       M. Fabian
# 189             LOS  Label50            12          16      Y. Regasel
# 190        PO ZRAKU  Label50            12          16      Y. Regasel
# 191       IZ VOLEJA  Label50            12          16      Y. Regasel
# 192      DESNA NOGA  Label50            12          16      Y. Regasel
# 193        PO ZRAKU  Label66             8           8    H. Seferovic
# 194          GLAVOM  Label66             8           8    H. Seferovic
# 195       PO ZEMLJI  Label53             8           8    H. Seferovic
# 196             LOS  Label53             8           8    H. Seferovic
# 197     LIJEVA NOGA  Label53             8           8    H. Seferovic
# 198        PO ZRAKU  Label66            12          12      L. Abraham
# 199          GLAVOM  Label66            12          12      L. Abraham
#
#      Source  Target     Label
# 0         1      20   12.89 8
# 1         1      20   12.89 8
# 2         1      20   12.89 8
# 3         2      21    5.46 9
# 4         2      21    5.46 9
# 5         2      21    5.46 9
# 6         3      21    4.34 5
# 7         3      21    4.34 5
# 8         3      21    4.34 5
# 9         1      22    2.09 5
# 10        1      22    2.09 5
# 11        1      22    2.09 5
# 12        4      23     3.7 9
# 13        4      23     3.7 9
# 14        5      24  12.58 12
# 15        5      24  12.58 12
# 16        5      20    8.37 8
# 17        5      20    8.37 8
# 18        1      25   16.01 7
# 19        1      25   16.01 7
# 20        1      25   16.01 7
# 21        1      25   16.01 7
# 22        5      26  18.26 12
# 23        5      26  18.26 12
# 24        3      27  11.16 12
# 25        3      27  11.16 12
# 26        2      28   29.86 2
# 27        2      28   29.86 2
# 28        2      28   29.86 2
# 29        2      28   29.86 2
# ..      ...     ...       ...
# 170       3      29   21.79 9
# 171       7      30   46.64 9
# 172       7      30   46.64 9
# 173       7      30   46.64 9
# 174      17      39   11.13 8
# 175      17      39   11.13 8
# 176       3      40   13.6 12
# 177       3      40   13.6 12
# 178       3      40   13.6 12
# 179      18      20    5.19 8
# 180      18      20    5.19 8
# 181       3      31   11.06 8
# 182       3      31   11.06 8
# 183      17      20   9.82 12
# 184      17      20   9.82 12
# 185      17      20   9.82 12
# 186      13      26   23.36 7
# 187      13      26   23.36 7
# 188      13      26   23.36 7
# 189      19      30  17.75 12
# 190      19      30  17.75 12
# 191      19      30  17.75 12
# 192      19      30  17.75 12
# 193       3      21    5.43 8
# 194       3      21    5.43 8
# 195       3      29   10.04 8
# 196       3      29   10.04 8
# 197       3      29   10.04 8
# 198       6      21   6.44 12
# 199       6      21   6.44 12
#
# [200 rows x 12 columns]

# %% [markdown]
# # Priprema podataka o primljenim golovima naših golmana

# %%
dfEintrachtPrimljeniGolovi = dfEintrachtAkcije[(dfEintrachtAkcije['actionID'] == 156)]

dfEintrachtPrimljeniGoloviClean = dfEintrachtPrimljeniGolovi.drop(['ID','gameID', 'actionID',
                                            'bindedActionID', 'actionOptionID',
                                            'playerTeam', 'refPositionX',
                                            'refPositionY', 'startPossTime', 'endPossTime', 'gameTimeSection',
                                            'playerPositionID', 'targetPositionID', 'awayTeamSide', 'action_duration',
                                            'domaci', 'gosti', 'domaciFormacija', 'gostiFormacija',
                                            'gameDate', 'gameTime', 'stadium', 'referee', 'stadium', 'climate',
                                            'luna', 'temperature', 'viewers', 'domaciID', 'gostiID', 'homeTeamFormacijaID',
                                            'awayTeamFormacijaID', 'Pogodaka_domaci', 'Score_domaci', 'Pogodaka_gosti',
                                            'Score_gosti', 'actionStartTime', 'actionEndTime', 'touchNumber',
                                            'ref_sector', 'poss_duration', 'targetPlayerID', 'targetPositionIDN'], axis = 1)

dfEintrachtPrimljeniGoloviClean.reset_index(drop=True, inplace=True)
dfEintrachtPrimljeniGoloviClean.to_csv("Eintracht_sna_primljeni_golovi.csv", sep=',', index=False)
dfEintrachtPrimljeniGoloviClean
# Out:
#     playerID playerPositionIDN actionIDNaziv bindedActionIDN actionOptionIDN  \
# 0       8570                GK  PRIMLJEN GOL  UDARAC U OKVIR  UDARAC U OKVIR
# 1       8570                GK  PRIMLJEN GOL  UDARAC U OKVIR  UDARAC U OKVIR
# 2       8570                GK  PRIMLJEN GOL  UDARAC U OKVIR  UDARAC U OKVIR
# 3       8570                GK  PRIMLJEN GOL  UDARAC U OKVIR  UDARAC U OKVIR
# 4       8570                GK  PRIMLJEN GOL  UDARAC U OKVIR  UDARAC U OKVIR
# 5       8570                GK  PRIMLJEN GOL  UDARAC U OKVIR  UDARAC U OKVIR
# 6       8570                GK  PRIMLJEN GOL  UDARAC U OKVIR  UDARAC U OKVIR
# 7       8570                GK  PRIMLJEN GOL  UDARAC U OKVIR  UDARAC U OKVIR
# 8       8570                GK  PRIMLJEN GOL  UDARAC U OKVIR  UDARAC U OKVIR
# 9       8570                GK  PRIMLJEN GOL  UDARAC U OKVIR  UDARAC U OKVIR
# 10      8570                GK  PRIMLJEN GOL  UDARAC U OKVIR  UDARAC U OKVIR
# 11      8570                GK  PRIMLJEN GOL  UDARAC U OKVIR  UDARAC U OKVIR
# 12      8570                GK  PRIMLJEN GOL  UDARAC U OKVIR  UDARAC U OKVIR
# 13      8570                GK  PRIMLJEN GOL  UDARAC U OKVIR  UDARAC U OKVIR
# 14      8570                GK  PRIMLJEN GOL  UDARAC U OKVIR  UDARAC U OKVIR
# 15      8570                GK  PRIMLJEN GOL  UDARAC U OKVIR  UDARAC U OKVIR
# 16      8570                GK  PRIMLJEN GOL  UDARAC U OKVIR  UDARAC U OKVIR
# 17      8570                GK  PRIMLJEN GOL  UDARAC U OKVIR  UDARAC U OKVIR
# 18      8570                GK  PRIMLJEN GOL  UDARAC U OKVIR  UDARAC U OKVIR
# 19      8570                GK  PRIMLJEN GOL  UDARAC U OKVIR  UDARAC U OKVIR
# 20      8570                GK  PRIMLJEN GOL  UDARAC U OKVIR  UDARAC U OKVIR
# 21      8570                GK  PRIMLJEN GOL  UDARAC U OKVIR  UDARAC U OKVIR
# 22      8570                GK  PRIMLJEN GOL  UDARAC U OKVIR  UDARAC U OKVIR
#
#     actionPosX1  actionPosX2  actionPosY1  actionPosY2  goalZone  distance  \
# 0          1227         1294       392.32       403.32   Label44      5.46
# 1          1128         1295       299.32       437.32   Label40     17.88
# 2           284           50       523.32       390.32   Label25     21.98
# 3           123           50       389.32       394.32   Label46      5.88
# 4           186           50       459.32       395.32   Label45     12.22
# 5          1216         1295       459.32       452.32   Label25      6.37
# 6          1257         1295       446.32       435.32   Label38      3.19
# 7           109           50       390.32       401.32   Label28      4.83
# 8           193           50       438.32       448.32    Label9     11.52
# 9           144           50       393.32       407.32    Label8      7.64
# 10         1086         1295       295.32       395.32   Label26     18.85
# 11         1249         1295       356.32       399.32   Label11      5.21
# 12          181           50       361.32       437.32   Label43     12.37
# 13         1139         1295       433.32       454.32   Label45     12.66
# 14         1250         1295       413.32       409.32  Label104      3.63
# 15          119           50       390.32       438.32   Label21      6.90
# 16          193           50       419.32       445.32   Label42     11.70
# 17         1208         1294       396.32       431.32   Label41      7.53
# 18          173           51       530.32       446.32   Label33     12.16
# 19         1191         1293       403.32       402.32   Label43      8.19
# 20         1108         1295       429.32       394.32  Label101     15.32
# 21         1166         1295       264.32       440.32   Label36     18.30
# 22         1155         1295       421.32       384.32   Label37     11.68
#
#     start_sector  end_sector
# 0              8           8
# 1              8           8
# 2              9           5
# 3              5           5
# 4              9           5
# 5             12          12
# 6              8           8
# 7              5           5
# 8              5           5
# 9              5           5
# 10             8           8
# 11             8           8
# 12             5           5
# 13             8          12
# 14             8           8
# 15             5           5
# 16             5           5
# 17             8           8
# 18             9           5
# 19             8           8
# 20             8           8
# 21             8           8
# 22             8           8

# %% [markdown]
# # Priprema čvorova za primljene golove našeg golmana

# %%
dfsource1 = dfEintrachtPrimljeniGoloviClean['start_sector']
dftarget1 = dfEintrachtPrimljeniGoloviClean['goalZone']

frames1 = [dfsource1, dftarget1]

dfNodespg = pd.concat(frames1)
dfNodespgClean = dfNodespg.drop_duplicates()
dfNodespgClean.reset_index(drop=True, inplace=True)
dfNodespgClean.index += 1
dfNodespgClean.to_csv("Eintracht_sna_primljeni_golovi_nodes.csv", sep=',', index=True)

# %% [markdown]
# # Priprema bridova za primljene golove našeg golmana

# %%
dfEintrachtpg = pd.read_csv("Eintracht_sna_primljeni_golovi.csv", sep=',')
dfEintrachtNodespg = pd.read_csv("Eintracht_sna_primljeni_golovi_nodes.csv", sep=',',names=['ID', 'Label'])

for indexpg, itempg in dfEintrachtpg.iterrows():
    for indexpgn, itempgn in dfEintrachtNodespg.iterrows():
        if(str(itempg['start_sector']) == str(itempgn['Label'])):
            ID = itempgn['ID']
            dfEintrachtpg.set_value(indexpg, 'Source', ID)
            
for indexpg, itempg in dfEintrachtpg.iterrows():
    for indexpgn, itempgn in dfEintrachtNodespg.iterrows():
        if(itempg['goalZone'] == itempgn['Label']):
            ID = itempgn['ID']
            dfEintrachtpg.set_value(indexpg, 'Target', ID)

dfEintrachtpgRenamed = dfEintrachtpg.rename(columns={'distance':'Weight'})
dfEintrachtpgRenamed.to_csv("Eintracht_sna_primljeni_golovi_edges.csv", sep=',', index=False)

# %% [markdown]
# # Priprema podataka o danim golovima naših igrača

# %%
dfEintrachtDaniGolovi = dfEintrachtAkcije[(dfEintrachtAkcije['actionID'] == 1)]

dfEintrachtDaniGoloviClean = dfEintrachtDaniGolovi.drop(['ID','gameID', 'actionID',
                                            'bindedActionID', 'actionOptionID',
                                            'playerTeam', 'refPositionX',
                                            'refPositionY', 'startPossTime', 'endPossTime', 'gameTimeSection',
                                            'playerPositionID', 'targetPositionID', 'awayTeamSide', 'action_duration',
                                            'domaci', 'gosti', 'domaciFormacija', 'gostiFormacija',
                                            'gameDate', 'gameTime', 'stadium', 'referee', 'stadium', 'climate',
                                            'luna', 'temperature', 'viewers', 'domaciID', 'gostiID', 'homeTeamFormacijaID',
                                            'awayTeamFormacijaID', 'Pogodaka_domaci', 'Score_domaci', 'Pogodaka_gosti',
                                            'Score_gosti', 'actionStartTime', 'actionEndTime', 'touchNumber',
                                            'ref_sector', 'poss_duration', 'targetPlayerID', 'targetPositionIDN'], axis = 1)

dfEintrachtDaniGoloviClean.reset_index(drop=True, inplace=True)
dfEintrachtDaniGoloviClean.to_csv("Eintracht_sna_primljeni_golovi.csv", sep=',', index=False)
dfEintrachtDaniGoloviClean2 = dfEintrachtDaniGoloviClean.drop(dfEintrachtAtrUdarciClean.index[6])
dfEintrachtDaniGoloviClean2.reset_index(drop=True, inplace=True)
dfEintrachtDaniGoloviClean2.index += 1

dfEP = pd.read_csv("eintrachtP.csv", sep=',')

dfEintrachtdg = pd.merge(dfEintrachtDaniGoloviClean2, dfEP, left_on='playerID', right_on='playerID', how='left')
dfEintrachtdg2 = dfEintrachtdg.rename(columns={'name_x':'playerName', 'name_y':'targetName', 'playerID_x':'playerID'})
dfEintrachtdg2.index += 1
dfEintrachtdg2.to_csv("Eintracht_sna_dani_golovi.csv", sep=',', index=False)
dfEintrachtdg2
# Out:
#     playerID playerPositionIDN actionIDNaziv bindedActionIDN  actionOptionIDN  \
# 1      40700               RCM           GOL               0           GLAVOM
# 2      77888                ST           GOL               0  PLASIRANA LOPTA
# 3       1802               LCM           GOL               0            NOGOM
# 4       1802               CAM           GOL               0           GLAVOM
# 5      16520                RW           GOL               0            NOGOM
# 6       1802               CAM           GOL               0            VOLEJ
# 7       1802               CAM           GOL               0            NOGOM
# 8       1802                ST           GOL               0            NOGOM
# 9       1770                LW           GOL               0            NOGOM
# 10      1802                ST           GOL               0            NOGOM
# 11      1790                CM           GOL               0           GLAVOM
#
#     actionPosX1  actionPosX2  actionPosY1  actionPosY2  goalZone  distance  \
# 1           106           50       389.32       399.32    Label2      4.58
# 2           227           50       282.32       451.32   Label26     20.30
# 3           363           51       385.32       450.32   Label20     25.68
# 4           119           50       420.32       403.32   Label28      5.73
# 5          1190         1295       459.32       421.32  Label105      9.04
# 6          1133         1295       404.32       444.32   Label35     13.46
# 7          1217         1295       361.32       423.32   Label41      8.21
# 8          1254         1295       391.32       407.32   Label22      3.56
# 9          1169         1295       450.32       442.32   Label28     10.14
# 10         1212         1295       381.32       401.32   Label22      6.88
# 11         1234         1295       385.32       443.32   Label23      6.98
#
#     start_sector  end_sector          name
# 1              5           5  S. Medojevic
# 2              5           9  H. Seferovic
# 3              6           9      A. Meier
# 4              5           5      A. Meier
# 5             12           8     S. Aigner
# 6              8           8      A. Meier
# 7              8           8      A. Meier
# 8              8           8      A. Meier
# 9             12           8     S. Huszti
# 10             8           8      A. Meier
# 11             8           8       M. Russ

# %% [markdown]
# # Priprema čvorova za dane golove naših igrača

# %%
dfsource2 = dfEintrachtdg2['name']
dftarget2 = dfEintrachtdg2['goalZone']

frames2 = [dfsource2, dftarget2]

dfNodesdg = pd.concat(frames2)
dfNodesdgClean = dfNodesdg.drop_duplicates()
dfNodesdgClean.reset_index(drop=True, inplace=True)
dfNodesdgClean.index += 1
dfNodesdgClean.to_csv("Eintracht_sna_dani_golovi_nodes.csv", sep=',', index=True)

# %% [markdown]
# # Priprema bridova za dane golove naših igrača

# %%
dfEintrachtdg = pd.read_csv("Eintracht_sna_dani_golovi.csv", sep=',')
dfEintrachtNodesdg = pd.read_csv("Eintracht_sna_dani_golovi_nodes.csv", sep=',',names=['ID', 'Label'])

for indexdg, itemdg in dfEintrachtdg.iterrows():
    for indexdgn, itemdgn in dfEintrachtNodesdg.iterrows():
        if(str(itemdg['name']) == str(itemdgn['Label'])):
            ID = itemdgn['ID']
            dfEintrachtdg.set_value(indexdg, 'Source', ID)
            
for indexdg, itemdg in dfEintrachtdg.iterrows():
    for indexdgn, itemdgn in dfEintrachtNodesdg.iterrows():
        if(itemdg['goalZone'] == itemdgn['Label']):
            ID = itemdgn['ID']
            dfEintrachtdg.set_value(indexdg, 'Target', ID)
            
dfEintrachtdgRenamed = dfEintrachtdg.rename(columns={'distance':'Weight'})
dfEintrachtdgRenamed.to_csv("Eintracht_sna_dani_golovi_edges.csv", sep=',', index=False)

# %% [markdown]
# # Priprema podataka za actionOptionID 376 (Izgubljen na liniju). Objašnjenje je na Driveu za tu vrstu akcije.

# %%
dfEintrachtINL = dfEintrachtAkcije[(dfEintrachtAkcije['actionOptionID'] == 376)]

dfEintrachtINLClean = dfEintrachtINL.drop([ 'gameID', 'actionID',
                                            'bindedActionID', 'actionOptionID',
                                            'playerTeam', 'refPositionX',
                                            'refPositionY', 'startPossTime', 'endPossTime', 'gameTimeSection',
                                            'playerPositionID', 'targetPositionID', 'awayTeamSide', 'action_duration',
                                            'domaci', 'gosti', 'domaciFormacija', 'gostiFormacija',
                                            'gameDate', 'gameTime', 'stadium', 'referee', 'stadium', 'climate',
                                            'luna', 'temperature', 'viewers', 'domaciID', 'gostiID', 'homeTeamFormacijaID',
                                            'awayTeamFormacijaID', 'Pogodaka_domaci', 'Score_domaci', 'Pogodaka_gosti',
                                            'Score_gosti', 'actionStartTime', 'actionEndTime', 'touchNumber',
                                            'ref_sector', 'poss_duration', 'goalZone', 'distance', 
                                            'targetPositionIDN'], axis = 1)

dfEintrachtINLClean.reset_index(drop=True, inplace=True)
dfEintrachtINLClean.index += 1

dfEintrachtINLClean1 = dfEintrachtINLClean[dfEintrachtINLClean['playerID'] ==
                                          dfEintrachtINLClean['targetPlayerID']]
dfEP = pd.read_csv("eintrachtP.csv", sep=',')

dfEintrachtINL1 = pd.merge(dfEintrachtINLClean1, dfEP, left_on='playerID', right_on='playerID', how='left')
dfEintrachtINL2 = dfEintrachtINL1.rename(columns={'name_x':'playerName', 'name_y':'targetName', 'playerID_x':'playerID'})
dfEintrachtINL2.to_csv("Eintracht_sna_inl.csv", sep=',', index=False)
dfEintrachtINL2.index += 1
dfEintrachtINL2
# Out:
#         ID  playerID playerPositionIDN                         actionIDNaziv  \
# 1  6257040    199745               RCM  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 2  6263901    199745               RCM  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 3  6314901    196633                LB  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 4  6605137      5335                RB  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 5  6631164    199745               LCM  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 6  6866705     16520                RW  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
#
#      bindedActionIDN      actionOptionIDN  targetPlayerID  actionPosX1  \
# 1        PREKID IGRE  IZGUBLJEN NA LINIJU          199745          502
# 2  NETOCNO DODAVANJE  IZGUBLJEN NA LINIJU          199745         1048
# 3        PREKID IGRE  IZGUBLJEN NA LINIJU          196633          458
# 4        PREKID IGRE  IZGUBLJEN NA LINIJU            5335          296
# 5        PREKID IGRE  IZGUBLJEN NA LINIJU          199745          973
# 6        PREKID IGRE  IZGUBLJEN NA LINIJU           16520          830
#
#    actionPosX2  actionPosY1  actionPosY2  start_sector  end_sector  \
# 1          462       317.32       349.32             6           6
# 2         1175       162.32       283.32             3           8
# 3          531        96.32       323.32             2           6
# 4          474       683.32       490.32            13          10
# 5          917       610.32       470.32            11          11
# 6          852        96.32       288.32             3           7
#
#           name
# 1  M. Stendera
# 2  M. Stendera
# 3   B. Oczipka
# 4    M. Hasebe
# 5  M. Stendera
# 6    S. Aigner

# %% [markdown]
# # Priprema čvorova za IZGUBLJEN NA LINIJU

# %%
dfsource3 = dfEintrachtINL2['start_sector']
dftarget3 = dfEintrachtINL2['end_sector']

frames3 = [dfsource3, dftarget3]

dfNodesINL = pd.concat(frames3)
dfNodesINLClean = dfNodesINL.drop_duplicates()
dfNodesINLClean.reset_index(drop=True, inplace=True)
dfNodesINLClean.index += 1
dfNodesINLClean.to_csv("Eintracht_sna_inl_nodes.csv", sep=',', index=True)

# %% [markdown]
# # Priprema bridova za IZGUBLJEN NA LINIJU

# %%
dfEintrachtINL1 = pd.read_csv("Eintracht_sna_inl.csv", sep=',')
dfEintrachtNodesINL = pd.read_csv("Eintracht_sna_inl_nodes.csv", sep=',',names=['ID', 'Label'])

for indexINL, itemINL in dfEintrachtINL1.iterrows():
    for indexINLn, itemINLn in dfEintrachtNodesINL.iterrows():
        if(str(itemINL['start_sector']) == str(itemINLn['Label'])):
            ID = itemINLn['ID']
            dfEintrachtINL1.set_value(indexINL, 'Source', ID)
            
for indexINL, itemINL in dfEintrachtINL1.iterrows():
    for indexINLn, itemINLn in dfEintrachtNodesINL.iterrows():
        if(itemINL['end_sector'] == itemINLn['Label']):
            ID = itemINLn['ID']
            dfEintrachtINL1.set_value(indexINL, 'Target', ID)
            
dfEintrachtINL1.index += 1
dfEintrachtINL1.to_csv("Eintracht_sna_inl_edges.csv", sep=',', index=False)

# %% [markdown]
# # Priprema podataka za IZGUBLJEN OD LINIJE

# %%
dfEintrachtIOL = dfEintrachtAkcije[(dfEintrachtAkcije['actionOptionID'] == 377)]

dfEintrachtIOLClean = dfEintrachtIOL.drop(['ID', 'gameID', 'actionID',
                                            'bindedActionID', 'actionOptionID',
                                            'playerTeam', 'refPositionX',
                                            'refPositionY', 'startPossTime', 'endPossTime', 'gameTimeSection',
                                            'playerPositionID', 'targetPositionID', 'awayTeamSide', 'action_duration',
                                            'domaci', 'gosti', 'domaciFormacija', 'gostiFormacija',
                                            'gameDate', 'gameTime', 'stadium', 'referee', 'stadium', 'climate',
                                            'luna', 'temperature', 'viewers', 'domaciID', 'gostiID', 'homeTeamFormacijaID',
                                            'awayTeamFormacijaID', 'Pogodaka_domaci', 'Score_domaci', 'Pogodaka_gosti',
                                            'Score_gosti', 'actionStartTime', 'actionEndTime', 'touchNumber',
                                            'ref_sector', 'poss_duration', 'goalZone', 'distance'], axis = 1)

dfEintrachtIOLClean.reset_index(drop=True, inplace=True)
dfEintrachtIOLClean.index += 1

dfEP = pd.read_csv("eintrachtP.csv", sep=',')

dfEintrachtIOL1 = pd.merge(dfEintrachtIOLClean, dfEP, left_on='playerID', right_on='playerID', how='left')
dfEintrachtIOL2 = dfEintrachtIOL1.rename(columns={'name_x':'playerName', 'name_y':'targetName', 'playerID_x':'playerID'})
dfEintrachtIOL2.to_csv("Eintracht_sna_iol.csv", sep=',', index=False)
dfEintrachtIOL2.index += 1
dfEintrachtIOL2
# Out:
#    playerID playerPositionIDN                         actionIDNaziv  \
# 1      5335                RB  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 2    196661               RCM  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 3    196633                LB  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 4    212914                RB  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 5      5335                LB  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 6    212914                RB  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 7     21022               LCB  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
#
#      bindedActionIDN      actionOptionIDN  targetPlayerID targetPositionIDN  \
# 1  NETOCNO DODAVANJE  IZGUBLJEN OD LINIJE           39442               RCB
# 2    TOCNO DODAVANJE  IZGUBLJEN OD LINIJE          116414                RW
# 3    TOCNO DODAVANJE  IZGUBLJEN OD LINIJE           54495                RW
# 4    TOCNO DODAVANJE  IZGUBLJEN OD LINIJE           29485                ST
# 5  NETOCNO DODAVANJE  IZGUBLJEN OD LINIJE          212914                RB
# 6            GOL OUT  IZGUBLJEN OD LINIJE               0                 0
# 7  NETOCNO DODAVANJE  IZGUBLJEN OD LINIJE          143853                LW
#
#    actionPosX1  actionPosX2  actionPosY1  actionPosY2  start_sector  \
# 1         1230         1214       173.32       389.32             4
# 2          792         1150       199.32       528.32             3
# 3          197          241       149.32       212.32             1
# 4           81          172       686.32       483.32            13
# 5          190          157       156.32       459.32             1
# 6          186           29       688.32       529.32            13
# 7          726          852       575.32       542.32            11
#
#    end_sector          name
# 1           8     M. Hasebe
# 2          12  A. Ignjovski
# 3           1    B. Oczipka
# 4           9    Y. Regasel
# 5           9     M. Hasebe
# 6           9    Y. Regasel
# 7          11    L. Abraham

# %% [markdown]
# # Priprema čvorova za IZGUBLJEN OD LINIJE

# %%
dfsource4 = dfEintrachtIOL2['start_sector']
dftarget4 = dfEintrachtIOL2['end_sector']

frames4 = [dfsource4, dftarget4]

dfNodesIOL = pd.concat(frames4)
dfNodesIOLClean = dfNodesIOL.drop_duplicates()
dfNodesIOLClean.reset_index(drop=True, inplace=True)
dfNodesIOLClean.index += 1
dfNodesIOLClean.to_csv("Eintracht_sna_iol_nodes.csv", sep=',', index=True)

# %% [markdown]
# # Priprema bridova za IZGUBLJEN OD LINIJE

# %%
dfEintrachtIOL1 = pd.read_csv("Eintracht_sna_iol.csv", sep=',')
dfEintrachtNodesIOL = pd.read_csv("Eintracht_sna_iol_nodes.csv", sep=',',names=['ID', 'Label'])

for indexIOL, itemIOL in dfEintrachtIOL1.iterrows():
    for indexIOLn, itemIOLn in dfEintrachtNodesIOL.iterrows():
        if(str(itemIOL['start_sector']) == str(itemIOLn['Label'])):
            ID = itemIOLn['ID']
            dfEintrachtIOL1.set_value(indexIOL, 'Source', ID)
            
for indexIOL, itemIOL in dfEintrachtIOL1.iterrows():
    for indexIOLn, itemIOLn in dfEintrachtNodesIOL.iterrows():
        if(itemIOL['end_sector'] == itemIOLn['Label']):
            ID = itemIOLn['ID']
            dfEintrachtIOL1.set_value(indexIOL, 'Target', ID)
            
dfEintrachtIOL1.index += 1
dfEintrachtIOL1.to_csv("Eintracht_sna_iol_edges.csv", sep=',', index=False)

# %% [markdown]
# # Priprema podataka za IZGUBLJEN U ZADNJOJ LINIJI

# %%
dfEintrachtIZL = dfEintrachtAkcije[(dfEintrachtAkcije['actionOptionID'] == 378)]

dfEintrachtIZLClean = dfEintrachtIZL.drop(['ID', 'gameID', 'actionID',
                                            'bindedActionID', 'actionOptionID',
                                            'playerTeam', 'refPositionX',
                                            'refPositionY', 'startPossTime', 'endPossTime', 'gameTimeSection',
                                            'playerPositionID', 'targetPositionID', 'awayTeamSide', 'action_duration',
                                            'domaci', 'gosti', 'domaciFormacija', 'gostiFormacija',
                                            'gameDate', 'gameTime', 'stadium', 'referee', 'stadium', 'climate',
                                            'luna', 'temperature', 'viewers', 'domaciID', 'gostiID', 'homeTeamFormacijaID',
                                            'awayTeamFormacijaID', 'Pogodaka_domaci', 'Score_domaci', 'Pogodaka_gosti',
                                            'Score_gosti', 'actionStartTime', 'actionEndTime', 'touchNumber',
                                            'ref_sector', 'poss_duration', 'goalZone', 'distance'], axis = 1)

dfEintrachtIZLClean.reset_index(drop=True, inplace=True)
dfEintrachtIZLClean.index += 1

dfEP = pd.read_csv("eintrachtP.csv", sep=',')

dfEintrachtIZL1 = pd.merge(dfEintrachtIZLClean, dfEP, left_on='playerID', right_on='playerID', how='left')
dfEintrachtIZL2 = dfEintrachtIZL1.rename(columns={'name_x':'playerName', 'name_y':'targetName', 'playerID_x':'playerID'})
dfEintrachtIZL2.to_csv("Eintracht_sna_izl.csv", sep=',', index=False)
dfEintrachtIZL2.index += 1
dfEintrachtIZL2
# Out:
#     playerID playerPositionIDN                         actionIDNaziv  \
# 1      21022               LCB  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 2      39442               RCB  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 3     196633                LB  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 4       5335                RB  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 5      21022               LCB  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 6      16520                RW  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 7      39442               RCB  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 8     196633                LB  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 9      39442               RCB  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 10     21022               LCB  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 11     21022               LCB  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 12      5335               CDM  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 13     21022               LCB  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 14     12956                LB  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 15     21022               LCB  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 16    196633                LB  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 17    196661                RB  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 18      5335                RB  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 19     21022               LCB  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 20     21022               LCB  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 21     21022               LCB  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 22     21022               LCB  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 23     39442               RCB  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
#
#         bindedActionIDN             actionOptionIDN  targetPlayerID  \
# 1        UDARAC U OKVIR  IZGUBLJEN U ZADNJOJ LINIJI               0
# 2     NETOCNO DODAVANJE  IZGUBLJEN U ZADNJOJ LINIJI          199745
# 3       TOCNO DODAVANJE  IZGUBLJEN U ZADNJOJ LINIJI          156937
# 4       TOCNO DODAVANJE  IZGUBLJEN U ZADNJOJ LINIJI          116414
# 5     NETOCNO DODAVANJE  IZGUBLJEN U ZADNJOJ LINIJI          203576
# 6     NETOCNO DODAVANJE  IZGUBLJEN U ZADNJOJ LINIJI           21022
# 7       TOCNO DODAVANJE  IZGUBLJEN U ZADNJOJ LINIJI            5335
# 8     NETOCNO DODAVANJE  IZGUBLJEN U ZADNJOJ LINIJI            5335
# 9        UDARAC U OKVIR  IZGUBLJEN U ZADNJOJ LINIJI               0
# 10    NETOCNO DODAVANJE  IZGUBLJEN U ZADNJOJ LINIJI          196661
# 11              GOL OUT  IZGUBLJEN U ZADNJOJ LINIJI               0
# 12    NETOCNO DODAVANJE  IZGUBLJEN U ZADNJOJ LINIJI           12956
# 13      TOCNO DODAVANJE  IZGUBLJEN U ZADNJOJ LINIJI           39797
# 14       UDARAC U OKVIR  IZGUBLJEN U ZADNJOJ LINIJI               0
# 15  UDARAC IZVAN OKVIRA  IZGUBLJEN U ZADNJOJ LINIJI               0
# 16  UDARAC IZVAN OKVIRA  IZGUBLJEN U ZADNJOJ LINIJI               0
# 17      TOCNO DODAVANJE  IZGUBLJEN U ZADNJOJ LINIJI          210557
# 18    NETOCNO DODAVANJE  IZGUBLJEN U ZADNJOJ LINIJI            8570
# 19       UDARAC U OKVIR  IZGUBLJEN U ZADNJOJ LINIJI               0
# 20                  OUT  IZGUBLJEN U ZADNJOJ LINIJI               0
# 21  UDARAC IZVAN OKVIRA  IZGUBLJEN U ZADNJOJ LINIJI               0
# 22    NETOCNO DODAVANJE  IZGUBLJEN U ZADNJOJ LINIJI          196633
# 23       UDARAC U OKVIR  IZGUBLJEN U ZADNJOJ LINIJI               0
#
#    targetPositionIDN  actionPosX1  actionPosX2  actionPosY1  actionPosY2  \
# 1                  0          104           71       546.32       460.32
# 2                RCM         1201         1175       242.32       283.32
# 3                 ST          127          115       212.32       391.32
# 4                 RW          144          164       652.32       377.32
# 5                 LW          348          270       533.32       458.32
# 6                LCB         1169         1225       162.32       439.32
# 7                 RB         1139         1100       310.32       158.32
# 8                 RB          125          137       189.32       463.32
# 9                  0           80           91       526.32       456.32
# 10                RB         1186         1215       449.32       474.32
# 11                 0         1082         1308       479.32       284.32
# 12                LB          917         1025       288.32       515.32
# 13                RW         1177         1249       269.32       530.32
# 14                 0         1232         1280       475.32       468.32
# 15                 0          262           64       277.32       487.32
# 16                 0          255           64       306.32       487.32
# 17                LW          180          270       677.32       386.32
# 18                GK         1252         1263       251.32       365.32
# 19                 0          231           80       301.32       422.32
# 20                 0         1134          988       611.32        19.32
# 21                 0          212           69       356.32       484.32
# 22               LWB          134          136       171.32       278.32
# 23                 0          270           74       567.32       441.32
#
#     start_sector  end_sector          name
# 1              9           9    L. Abraham
# 2              8           8   C. Zambrano
# 3              1           5    B. Oczipka
# 4              9           5     M. Hasebe
# 5              9           9    L. Abraham
# 6              4           8     S. Aigner
# 7              8           4   C. Zambrano
# 8              1           9    B. Oczipka
# 9              9           9   C. Zambrano
# 10             8          12    L. Abraham
# 11            12           8    L. Abraham
# 12             7          11     M. Hasebe
# 13             8          12    L. Abraham
# 14            12          12     C. Djakpa
# 15             5           9    L. Abraham
# 16             5           9    B. Oczipka
# 17            13           5  A. Ignjovski
# 18             8           8     M. Hasebe
# 19             5           5    L. Abraham
# 20            12           3    L. Abraham
# 21             5           9    L. Abraham
# 22             1           5    L. Abraham
# 23             9           5   C. Zambrano

# %% [markdown]
# # Priprema čvorova za IZGUBLJEN U ZADNJOJ LINIJI

# %%
dfsource5 = dfEintrachtIZL2['name']
dftarget5 = dfEintrachtIZL2['start_sector']

frames5 = [dfsource5, dftarget5]

dfNodesIZL = pd.concat(frames5)
dfNodesIZLClean = dfNodesIZL.drop_duplicates()
dfNodesIZLClean.reset_index(drop=True, inplace=True)
dfNodesIZLClean.index += 1
dfNodesIZLClean.to_csv("Eintracht_sna_izl_nodes.csv", sep=',', index=True)

# %% [markdown]
# # Priprema bridova za IZGUBLJEN U ZADNJOJ LINIJI

# %%
dfEintrachtIZL1 = pd.read_csv("Eintracht_sna_izl.csv", sep=',')
dfEintrachtNodesIZL = pd.read_csv("Eintracht_sna_izl_nodes.csv", sep=',',names=['ID', 'Label'])

for indexIZL, itemIZL in dfEintrachtIZL1.iterrows():
    for indexIZLn, itemIZLn in dfEintrachtNodesIZL.iterrows():
        if(str(itemIZL['name']) == str(itemIZLn['Label'])):
            ID = itemIZLn['ID']
            dfEintrachtIZL1.set_value(indexIZL, 'Source', ID)
            
for indexIZL, itemIZL in dfEintrachtIZL1.iterrows():
    for indexIZLn, itemIZLn in dfEintrachtNodesIZL.iterrows():
        if(str(itemIZL['start_sector']) == str(itemIZLn['Label'])):
            ID = itemIZLn['ID']
            dfEintrachtIZL1.set_value(indexIZL, 'Target', ID)
            
dfEintrachtIZL1.index += 1
dfEintrachtIZL1.to_csv("Eintracht_sna_izl_edges.csv", sep=',', index=False)

# %% [markdown]
# # Priprema za asistencije prije gola

# %%
dfEintrachtAsistencijePG = dfEintrachtAkcije[(dfEintrachtAkcije['actionID'] == 342)]

dfEintrachtAsistencijePGClean = dfEintrachtAsistencijePG.drop(['ID', 'gameID', 'actionID',
                                            'bindedActionID', 'actionOptionID',
                                            'playerTeam', 'refPositionX',
                                            'refPositionY', 'startPossTime', 'endPossTime', 'gameTimeSection',
                                            'playerPositionID', 'targetPositionID', 'awayTeamSide', 'action_duration',
                                            'domaci', 'gosti', 'domaciFormacija', 'gostiFormacija',
                                            'gameDate', 'gameTime', 'stadium', 'referee', 'stadium', 'climate',
                                            'luna', 'temperature', 'viewers', 'domaciID', 'gostiID', 'homeTeamFormacijaID',
                                            'awayTeamFormacijaID', 'Pogodaka_domaci', 'Score_domaci', 'Pogodaka_gosti',
                                            'Score_gosti', 'actionStartTime', 'actionEndTime', 'touchNumber',
                                            'ref_sector', 'goalZone', 'distance'], axis = 1)

dfEintrachtAsistencijePGClean.reset_index(drop=True, inplace=True)
dfEintrachtAsistencijePGClean.index += 1

dfEP = pd.read_csv("eintrachtP.csv", sep=',')

dfEintrachtapg = pd.merge(dfEintrachtAsistencijePGClean, dfEP, left_on='playerID', right_on='playerID', how='left')
dfEintrachtapg2 = pd.merge(dfEintrachtapg, dfEP, left_on='targetPlayerID', right_on='playerID', how='left')
dfEintrachtapg3 = dfEintrachtapg2.drop('playerID_y', axis=1)
dfEintrachtapg4 = dfEintrachtapg3.rename(columns={'name_x':'playerName', 'name_y':'targetName', 'playerID_x':'playerID'})
dfEintrachtapg4['Weight'] = dfEintrachtapg4.groupby('playerID')['targetPlayerID'].transform(pd.Series.value_counts)
dfEintrachtapg4 = dfEintrachtapg4.drop_duplicates()
dfEintrachtapg4.to_csv("Eintracht_sna_asistencije_prije_gola.csv", sep=',', index=False)
dfEintrachtapg4.index += 1
dfEintrachtapg4
# Out:
#    playerID playerPositionIDN           actionIDNaziv  bindedActionIDN  \
# 1    199745               LCM  ASISTENCIJA PRIJE GOLA  TOCNO DODAVANJE
# 2     77888                ST  ASISTENCIJA PRIJE GOLA                0
# 3    196661                RB  ASISTENCIJA PRIJE GOLA                0
# 4     77888                ST  ASISTENCIJA PRIJE GOLA                0
# 5     16520                RW  ASISTENCIJA PRIJE GOLA                0
# 6     16520                RW  ASISTENCIJA PRIJE GOLA                0
# 7     22870               CAM  ASISTENCIJA PRIJE GOLA                0
# 8      1770                LW  ASISTENCIJA PRIJE GOLA                0
# 9     22870               LCF  ASISTENCIJA PRIJE GOLA                0
#
#     actionOptionIDN  targetPlayerID targetPositionIDN  actionPosX1  \
# 1         CENTARSUT           40700               RCM          183
# 2          POVRATNA            1802               LCM          287
# 3         CENTARSUT            1802               CAM          255
# 4          POVRATNA           16520                RW         1239
# 5            GLAVOM            1802               CAM         1131
# 6          POVRATNA            1802               CAM         1128
# 7         CENTARSUT            1770                LW         1291
# 8  PODVALJENA LOPTA            1802                ST         1044
# 9         CENTARSUT            1790                CM         1142
#
#    actionPosX2  actionPosY1  actionPosY2  poss_duration  start_sector  \
# 1          120       763.32       383.32           0.41            13
# 2          383       594.32       394.32           3.06             9
# 3          128       104.32       412.32           0.21             1
# 4         1192       610.32       462.32           2.28            12
# 5         1131       433.32       406.32           0.15             8
# 6         1079       530.32       465.32           1.53            12
# 7         1171        53.32       448.32           0.16             4
# 8         1211       286.32       377.32           0.13             7
# 9         1227       152.32       382.32           1.46             4
#
#    end_sector    playerName    targetName  Weight
# 1           5   M. Stendera  S. Medojevic       1
# 2           6  H. Seferovic      A. Meier       1
# 3           5  A. Ignjovski      A. Meier       1
# 4          12  H. Seferovic     S. Aigner       1
# 5           8     S. Aigner      A. Meier       2
# 6          12     S. Aigner      A. Meier       2
# 7           8     M. Fabian     S. Huszti       1
# 8           8     S. Huszti      A. Meier       1
# 9           8     M. Fabian       M. Russ       1

# %% [markdown]
# # Priprema čvorova za asistencije prije gola

# %%
dfNodesapg = dfEintrachtapg4[['playerID', 'playerName']]
dfNodesUniqueapg = dfNodesapg.drop_duplicates()
dfNodesUniqueRenamedapg = dfNodesUniqueapg.rename(columns={'playerID':'ID', 'playerName':'Label'})
dfNodesUniqueRenamedapg.to_csv("Eintracht_sna_asistencije_prije_gola_nodes.csv", sep=',', index=False)

# %% [markdown]
# # Priprema bridova za asistencije prije gola

# %%
dfEdgesapg = dfEintrachtapg4.rename(columns={'playerID':'Source', 'targetPlayerID':'Target', 'weight':'Weight'})
dfEdgesapg['Label'] = dfEdgesapg['end_sector'].map(str)
dfEdgesapg.to_csv("Eintracht_sna_asistencije_prije_gola_edges.csv", sep=',', index=False)
