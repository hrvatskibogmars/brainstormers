# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import warnings
warnings.filterwarnings('ignore')

dfSve = pd.read_csv("mozgalo_gladbach_eintracht_akcije_spojeno.csv", sep = ',')

maxDistance = dfSve['distance'].max()
distance = dfSve['distance']
distanceArray = np.array(distance)
medianDistance = np.median(distanceArray)
minDistance = dfSve['distance'].min()

print("Max: %s" % maxDistance)
print("Median: %s" % medianDistance)
print("Min: %s" % minDistance)
# Out:
# Max: 89.39
# Median: 13.6
# Min: 0.0

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import warnings
warnings.filterwarnings('ignore')

for index, item in dfSve.iterrows():
    if(item['distance'] >= 0 and item['distance'] <= 11.17):
        w = 1
        dfSve.set_value(index,'weight',w)
    elif(item['distance'] >= 11.17 and item['distance'] <= 22.34):
        w = 2
        dfSve.set_value(index,'weight',w)
    elif(item['distance'] >= 22.34 and item['distance'] <= 33.51):
        w = 3
        dfSve.set_value(index,'weight',w)
    elif(item['distance'] >= 33.51 and item['distance'] <= 44.68):
        w = 4
        dfSve.set_value(index,'weight',w)
    elif(item['distance'] >= 44.68 and item['distance'] <= 55.85):
        w = 5
        dfSve.set_value(index,'weight',w)
    elif(item['distance'] >= 55.85 and item['distance'] <= 67.02):
        w = 6
        dfSve.set_value(index,'weight',w)
    elif(item['distance'] >= 67.02 and item['distance'] <= 78.19):
        w = 7
        dfSve.set_value(index,'weight',w)
    elif(item['distance'] >= 78.19 and item['distance'] <= 89.36):
        w = 8
        dfSve.set_value(index,'weight',w)

# %% [markdown]
# Filtriranje stupaca i akcija samo naših igrača

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import warnings
warnings.filterwarnings('ignore')

igraci = [8570, 196633, 5335, 21022, 16520, 199745, 77888, 39442, 1802, 1790, 1770, 22870, 40700, 196661, 212914, 203576, 
          206101, 67519, 143853, 57720, 12956, 44079, 7466, 205986, 102895, 201624, 214449, 206102]

dfEintrachtAkcije = dfSve[dfSve['playerID'].isin(igraci)]
dfEintrachtAkcijeClean = dfEintrachtAkcije.drop(['gameID', 'actionID',
                                            'bindedActionID', 'actionOptionID',
                                            'playerTeam', 'goalZone', 'refPositionX',
                                            'refPositionY', 'startPossTime', 'endPossTime', 'gameTimeSection',
                                            'playerPositionID', 'targetPositionID', 'awayTeamSide', 'action_duration',
                                            'domaci', 'gosti', 'domaciFormacija', 'gostiFormacija',
                                            'gameDate', 'gameTime', 'stadium', 'referee', 'stadium', 'climate',
                                            'luna', 'temperature', 'viewers', 'domaciID', 'gostiID', 'homeTeamFormacijaID',
                                            'awayTeamFormacijaID', 'Pogodaka_domaci', 'Score_domaci', 'Pogodaka_gosti',
                                            'Score_gosti', 'actionStartTime', 'actionEndTime', 'touchNumber',
                                            'actionPosX1', 'actionPosX2', 'actionPosY1', 'actionPosY2',
                                            'ref_sector'], axis = 1)

dfEintrachtAkcijeClean1 = dfEintrachtAkcijeClean[dfEintrachtAkcijeClean['targetPlayerID'] != 0]
dfEintrachtAkcijeClean2 = dfEintrachtAkcijeClean1[(dfEintrachtAkcijeClean1['playerID'].isin(igraci)) & 
                                                  (dfEintrachtAkcijeClean1['targetPlayerID'].isin(igraci))]

# %%
dfEP = pd.read_csv("eintrachtP.csv", sep=',')

dfEintrachtIgraci = pd.merge(dfEintrachtAkcijeClean2, dfEP, left_on='playerID', right_on='playerID', how='left')
dfEintrachtIgraci2 = pd.merge(dfEintrachtIgraci, dfEP, left_on='targetPlayerID', right_on='playerID', how='left')
dfEintrachtIgraci3 = dfEintrachtIgraci2.drop('playerID_y', axis=1)
dfEintrachtIgraci4 = dfEintrachtIgraci3.rename(columns={'name_x':'playerName', 'name_y':'targetName', 'playerID_x':'playerID'})
dfEintrachtIgraci5 = dfEintrachtIgraci4.drop(['distance', 'ID'], axis=1)
dfEintrachtIgraci5.to_csv("Eintracht_sna_ukupno.csv", sep=',', index=False)
dfEintrachtIgraci5
# Out:
#       playerID playerPositionIDN                         actionIDNaziv  \
# 0        44079               LCM  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 1       199745               RCM  DEFANZIVNI DRIBLING 1 NA 1 IZGUBLJEN
# 2       196633                LB                       TOCNO DODAVANJE
# 3        21022               LCB                       TOCNO DODAVANJE
# 4        44079               LCM                       TOCNO DODAVANJE
# 5        21022               LCB                       TOCNO DODAVANJE
# 6       196633                LB                       TOCNO DODAVANJE
# 7       196661                LW                       TOCNO DODAVANJE
# 8       196661                LW                      OSTALA DODAVANJA
# 9       199745               RCM                       TOCNO DODAVANJE
# 10      199745               RCM                         ODUZETE LOPTE
# 11      199745               RCM                       NIJE IZGUBLJENA
# ...

# %% [markdown]
# Filitriranje samo točnih dodavanja

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import warnings
warnings.filterwarnings('ignore')

igraci = [8570, 196633, 5335, 21022, 16520, 199745, 77888, 39442, 1802, 1790, 1770, 22870, 40700, 196661, 212914, 203576, 
          206101, 67519, 143853, 57720, 12956, 44079, 7466, 205986, 102895, 201624, 214449, 206102]

dfEintrachtAkcije1 = dfSve[dfSve['playerID'].isin(igraci)]
dfEintrachtAkcijeT = dfEintrachtAkcije1[(dfEintrachtAkcije1['actionID'] == 247)]

dfEintrachtAkcijeClean1 = dfEintrachtAkcijeT.drop(['gameID', 'actionID',
                                            'bindedActionID', 'actionOptionID',
                                            'playerTeam', 'goalZone', 'refPositionX',
                                            'refPositionY', 'startPossTime', 'endPossTime', 'gameTimeSection',
                                            'playerPositionID', 'targetPositionID', 'awayTeamSide', 'action_duration',
                                            'domaci', 'gosti', 'domaciFormacija', 'gostiFormacija',
                                            'gameDate', 'gameTime', 'stadium', 'referee', 'stadium', 'climate',
                                            'luna', 'temperature', 'viewers', 'domaciID', 'gostiID', 'homeTeamFormacijaID',
                                            'awayTeamFormacijaID', 'Pogodaka_domaci', 'Score_domaci', 'Pogodaka_gosti',
                                            'Score_gosti', 'actionStartTime', 'actionEndTime', 'touchNumber',
                                            'actionPosX1', 'actionPosX2', 'actionPosY1', 'actionPosY2',
                                            'ref_sector'], axis = 1)

dfEintrachtAkcijeClean1T = dfEintrachtAkcijeClean1[dfEintrachtAkcijeClean1['targetPlayerID'] != 0]
dfEintrachtAkcijeClean2T = dfEintrachtAkcijeClean1T[(dfEintrachtAkcijeClean1T['playerID'].isin(igraci)) & 
                                                  (dfEintrachtAkcijeClean1T['targetPlayerID'].isin(igraci))]

# %%
dfEP1 = pd.read_csv("eintrachtP.csv", sep=',')

dfEintrachtIgraciT = pd.merge(dfEintrachtAkcijeClean2T, dfEP1, left_on='playerID', right_on='playerID', how='left')
dfEintrachtIgraci2T = pd.merge(dfEintrachtIgraciT, dfEP1, left_on='targetPlayerID', right_on='playerID', how='left')
dfEintrachtIgraci3T = dfEintrachtIgraci2T.drop('playerID_y', axis=1)
dfEintrachtIgraci4T = dfEintrachtIgraci3T.rename(columns={'name_x':'playerName', 'name_y':'targetName', 'playerID_x':'playerID'})
dfEintrachtIgraci5T = dfEintrachtIgraci4T.drop(['distance', 'ID'], axis=1)
dfEintrachtIgraci5T.to_csv("Eintracht_sna_tocna.csv", sep=',', index=False)
dfEintrachtIgraci5T
# Out:
#       playerID playerPositionIDN    actionIDNaziv bindedActionIDN  \
# 0       196633                LB  TOCNO DODAVANJE               0
# 1        21022               LCB  TOCNO DODAVANJE               0
# 2        44079               LCM  TOCNO DODAVANJE               0
# 3        21022               LCB  TOCNO DODAVANJE               0
# 4       196633                LB  TOCNO DODAVANJE               0
# 5       196661                LW  TOCNO DODAVANJE               0
# 6       199745               RCM  TOCNO DODAVANJE               0
# 7        21022               LCB  TOCNO DODAVANJE               0
# 8         5335                RB  TOCNO DODAVANJE               0
# 9        16520                RW  TOCNO DODAVANJE               0
# 10       77888                ST  TOCNO DODAVANJE               0
# 11       77888                ST  TOCNO DODAVANJE               0
# 12        1802               CAM  TOCNO DODAVANJE               0
# ...

# %% [markdown]
# Filtriranje samo netočnih dodavanja

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import warnings
warnings.filterwarnings('ignore')

igraci = [8570, 196633, 5335, 21022, 16520, 199745, 77888, 39442, 1802, 1790, 1770, 22870, 40700, 196661, 212914, 203576, 
          206101, 67519, 143853, 57720, 12956, 44079, 7466, 205986, 102895, 201624, 214449, 206102]

dfEintrachtAkcije2 = dfSve[dfSve['playerID'].isin(igraci)]
dfEintrachtAkcijeN = dfEintrachtAkcije2[(dfEintrachtAkcije2['actionID'] == 248)]

dfEintrachtAkcijeClean2 = dfEintrachtAkcijeN.drop(['ID', 'gameID', 'actionID',
                                            'bindedActionID', 'actionOptionID',
                                            'playerTeam', 'goalZone', 'refPositionX',
                                            'refPositionY', 'startPossTime', 'endPossTime', 'gameTimeSection',
                                            'playerPositionID', 'targetPositionID', 'awayTeamSide', 'action_duration',
                                            'domaci', 'gosti', 'domaciFormacija', 'gostiFormacija',
                                            'gameDate', 'gameTime', 'stadium', 'referee', 'stadium', 'climate',
                                            'luna', 'temperature', 'viewers', 'domaciID', 'gostiID', 'homeTeamFormacijaID',
                                            'awayTeamFormacijaID', 'Pogodaka_domaci', 'Score_domaci', 'Pogodaka_gosti',
                                            'Score_gosti', 'actionStartTime', 'actionEndTime', 'touchNumber',
                                            'actionPosX1', 'actionPosX2', 'actionPosY1', 'actionPosY2',
                                            'ref_sector'], axis = 1)

# %%
dfEP2 = pd.read_csv("eintrachtP.csv", sep=',')

dfEintrachtIgraci2N = pd.merge(dfEintrachtAkcijeClean2, dfEP2, left_on='playerID', right_on='playerID', how='left')
dfEintrachtIgraci4N = dfEintrachtIgraci3N.rename(columns={'name_x':'playerName', 'name_y':'targetName', 'playerID_x':'playerID'})
dfEintrachtIgraci5N = dfEintrachtIgraci4N.drop(['distance', 'ID'], axis=1)
dfEintrachtIgraci5N.to_csv("Eintracht_sna_netocna.csv", sep=',', index=False)
dfEintrachtIgraci2N
# Out:
#       playerID playerPositionIDN      actionIDNaziv bindedActionIDN  \
# 0       196633                LB  NETOCNO DODAVANJE               0
# 1       199745               RCM  NETOCNO DODAVANJE               0
# 2        44079               LCM  NETOCNO DODAVANJE               0
# 3       196633                LB  NETOCNO DODAVANJE               0
# 4       196633                LB  NETOCNO DODAVANJE               0
# 5        77888                ST  NETOCNO DODAVANJE               0
# 6       196661                LW  NETOCNO DODAVANJE               0
# 7       199745               RCM  NETOCNO DODAVANJE               0
# 8       196661                LW  NETOCNO DODAVANJE               0
# 9         1802               CAM  NETOCNO DODAVANJE               0
# 10       16520                RW  NETOCNO DODAVANJE               0
# 11      196633                LB  NETOCNO DODAVANJE               0
# 12       16520                RW  NETOCNO DODAVANJE               0
# ...
