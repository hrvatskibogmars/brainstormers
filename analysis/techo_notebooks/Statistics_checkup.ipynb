# %% [markdown]
# ## Atribut 'temperature' iz utakmice.csv

# %% [markdown]
# Srednja vrijednost i medijan su jako blizu i to znači da za atribut temperature ne postoje vrijednosti koje jako odstupaju i koje bi narušavale taj odnos, ne postoje outliers. To znači da je senzor dobro mjeril i da je app dobro zapisala temperaturu.
# Mod je najčešća vrijednost koja se pojavljuje, znači 4 stupnja i to 8 puta.
# Standardna devijacija je odstupanje od srednje vrijednosti i unutar tog intervala, između srednje vrijednosti i standardne devijacije (u plus i u minus od srednje vrijednosti za vrijednost standardne devijacije) se nalazi najviše vrijednosti. Znači najviše vrijednosti se nalazi između 3.xx i 9.xx stupnja celzijusa.
#
# Sve isto vrijedi za svaki atribut.

# %%
import pandas as pd
import numpy as np
from scipy import stats
import os

fileDir = os.path.dirname(os.path.realpath('mozgalo_gladbach_eintracht_utakmice.csv'))
filename = os.path.join(fileDir, '../data/clean/mozgalo_gladbach_eintracht_utakmice.csv')
file = os.path.abspath(os.path.realpath(filename))
dataframe = pd.read_csv(file)
temp = dataframe["temperature"]
temparray = np.array(temp)

mean = np.mean(temparray)
median = np.median(temparray)
std_dev = np.std(temparray)
mode = stats.mode(temparray)

print("Srednja vrijednost: %s" % mean)
print("Medijan: %s" % median)
print("Standardna devijacija: %s" % std_dev)
print("Mod: %s" % mode[0], "Koliko puta se ta vrijednost pojavila: %s" % mode[1])
# Out:
# Srednja vrijednost: 6.83333333333
# Medijan: 7.0
# Standardna devijacija: 2.91070819943
# Mod: [4] Koliko puta se ta vrijednost pojavila: [8]

# %% [markdown]
# ## 'viewers' iz utakmice.csv'

# %%
import pandas as pd
import numpy as np
from scipy import stats
import os

fileDir = os.path.dirname(os.path.realpath('mozgalo_gladbach_eintracht_utakmice.csv'))
filename = os.path.join(fileDir, '../data/clean/mozgalo_gladbach_eintracht_utakmice.csv')
file = os.path.abspath(os.path.realpath(filename))
dataframe = pd.read_csv(file)
v = dataframe["viewers"]
varray = np.array(v)

mean = np.mean(varray)
median = np.median(varray)
std_dev = np.std(varray)
mode = stats.mode(varray)

print("Srednja vrijednost: %s" % mean)
print("Medijan: %s" % median)
print("Standardna devijacija: %s" % std_dev)
print("Mod: %s" % mode[0], "Koliko puta se ta vrijednost pojavila: %s" % mode[1])
# Out:
# Srednja vrijednost: 44011.3666667
# Medijan: 44402.0
# Standardna devijacija: 11371.4306297
# Mod: [30150] Koliko puta se ta vrijednost pojavila: [2]

# %% [markdown]
# ## 'touchNumber' iz akcije.csv

# %%
import pandas as pd
import numpy as np
from scipy import stats
import os

fileDir = os.path.dirname(os.path.realpath('mozgalo_gladbach_eintracht_akcije.csv'))
filename = os.path.join(fileDir, '../data/clean/mozgalo_gladbach_eintracht_akcije.csv')
file = os.path.abspath(os.path.realpath(filename))
dataframe = pd.read_csv(file)
t = dataframe["touchNumber"]
tarray = np.array(t)

mean = np.mean(tarray)
median = np.median(tarray)
std_dev = np.std(tarray)
mode = stats.mode(tarray)

print("Srednja vrijednost: %s" % mean)
print("Medijan: %s" % median)
print("Standardna devijacija: %s" % std_dev)
print("Mod: %s" % mode[0], "Koliko puta se ta vrijednost pojavila: %s" % mode[1])
# Out:
# Srednja vrijednost: 1.93837710256
# Medijan: 1.0
# Standardna devijacija: 1.62255314555
# Mod: [1] Koliko puta se ta vrijednost pojavila: [38596]

# %% [markdown]
# ## 'distance' iz akcije.csv

# %%
import pandas as pd
import numpy as np
from scipy import stats
import os

fileDir = os.path.dirname(os.path.realpath('mozgalo_gladbach_eintracht_akcije.csv'))
filename = os.path.join(fileDir, '../data/clean/mozgalo_gladbach_eintracht_akcije.csv')
file = os.path.abspath(os.path.realpath(filename))
dataframe = pd.read_csv(file)
d = dataframe["distance"]
darray = np.array(d)

mean = np.mean(darray)
median = np.median(darray)
std_dev = np.std(darray)
mode = stats.mode(darray)

print("Srednja vrijednost: %s" % mean)
print("Medijan: %s" % median)
print("Standardna devijacija: %s" % std_dev)
print("Mod: %s" % mode[0], "Koliko puta se ta vrijednost pojavila: %s" % mode[1])
# Out:
# Srednja vrijednost: 16.8273840838
# Medijan: 13.6
# Standardna devijacija: 13.2008294807
# Mod: [ 0.] Koliko puta se ta vrijednost pojavila: [1846]

# %% [markdown]
# ## 'actionPosX1' iz akcije.csv

# %%
import pandas as pd
import numpy as np
from scipy import stats
import os

fileDir = os.path.dirname(os.path.realpath('mozgalo_gladbach_eintracht_akcije.csv'))
filename = os.path.join(fileDir, '../data/clean/mozgalo_gladbach_eintracht_akcije.csv')
file = os.path.abspath(os.path.realpath(filename))
dataframe = pd.read_csv(file)
actionPosX1 = dataframe["actionPosX1"]
x1 = np.array(actionPosX1)

mean = np.mean(x1)
median = np.median(x1)
std_dev = np.std(x1)
mode = stats.mode(x1)

print("Srednja vrijednost: %s" % mean)
print("Medijan: %s" % median)
print("Standardna devijacija: %s" % std_dev)
print("Mod: %s" % mode[0], "Koliko puta se ta vrijednost pojavila: %s" % mode[1])
# Out:
# Srednja vrijednost: 676.200423711
# Medijan: 670.0
# Standardna devijacija: 329.059984375
# Mod: [0] Koliko puta se ta vrijednost pojavila: [170]

# %% [markdown]
# ## 'actionPosX2' iz akcije.csv

# %%
import pandas as pd
import numpy as np
from scipy import stats
import os

fileDir = os.path.dirname(os.path.realpath('mozgalo_gladbach_eintracht_akcije.csv'))
filename = os.path.join(fileDir, '../data/clean/mozgalo_gladbach_eintracht_akcije.csv')
file = os.path.abspath(os.path.realpath(filename))
dataframe = pd.read_csv(file)
actionPosX2 = dataframe["actionPosX2"]
x2 = np.array(actionPosX2)

mean = np.mean(x2)
median = np.median(x2)
std_dev = np.std(x2)
mode = stats.mode(x2)

print("Srednja vrijednost: %s" % mean)
print("Medijan: %s" % median)
print("Standardna devijacija: %s" % std_dev)
print("Mod: %s" % mode[0], "Koliko puta se ta vrijednost pojavila: %s" % mode[1])
# Out:
# Srednja vrijednost: 659.619285948
# Medijan: 652.0
# Standardna devijacija: 354.282131012
# Mod: [0] Koliko puta se ta vrijednost pojavila: [1828]

# %% [markdown]
# ## 'actionPosY1' iz akcije.csv

# %%
import pandas as pd
import numpy as np
from scipy import stats
import os

fileDir = os.path.dirname(os.path.realpath('mozgalo_gladbach_eintracht_akcije.csv'))
filename = os.path.join(fileDir, '../data/clean/mozgalo_gladbach_eintracht_akcije.csv')
file = os.path.abspath(os.path.realpath(filename))
dataframe = pd.read_csv(file)
actionPosY1 = dataframe["actionPosY1"]
y1 = np.array(actionPosY1)

mean = np.mean(y1)
median = np.median(y1)
std_dev = np.std(y1)
mode = stats.mode(y1)

print("Srednja vrijednost: %s" % mean)
print("Medijan: %s" % median)
print("Standardna devijacija: %s" % std_dev)
print("Mod: %s" % mode[0], "Koliko puta se ta vrijednost pojavila: %s" % mode[1])
# Out:
# Srednja vrijednost: 420.191174873
# Medijan: 423.32
# Standardna devijacija: 218.089596116
# Mod: [ 0.] Koliko puta se ta vrijednost pojavila: [170]

# %% [markdown]
# ## 'actionPosY2' iz akcije.csv

# %%
import pandas as pd
import numpy as np
from scipy import stats
import os

fileDir = os.path.dirname(os.path.realpath('mozgalo_gladbach_eintracht_akcije.csv'))
filename = os.path.join(fileDir, '../data/clean/mozgalo_gladbach_eintracht_akcije.csv')
file = os.path.abspath(os.path.realpath(filename))
dataframe = pd.read_csv(file)
actionPosY2 = dataframe["actionPosY2"]
y2 = np.array(actionPosY2)

mean = np.mean(y2)
median = np.median(y2)
std_dev = np.std(y2)
mode = stats.mode(y2)

print("Srednja vrijednost: %s" % mean)
print("Medijan: %s" % median)
print("Standardna devijacija: %s" % std_dev)
print("Mod: %s" % mode[0], "Koliko puta se ta vrijednost pojavila: %s" % mode[1])
# Out:
# Srednja vrijednost: 408.745375439
# Medijan: 414.32
# Standardna devijacija: 221.882770775
# Mod: [ 0.] Koliko puta se ta vrijednost pojavila: [1828]

# %% [markdown]
# ## 'refPositionX' iz akcije.csv

# %% [markdown]
# Srednja vrijednost i medijan jako različiti. To nije dobro, zato nam i jesu čudne vrijednosti za te atribute, za poziciju suca u svakoj ackiji. App ipak dobro bilježi poziciju suca jer ona je zabilježena svaki put kad sudac na nekaj reagira. Ovo dolje neka ostane, još možda posluži.

# %%
import pandas as pd
import numpy as np
from scipy import stats
import os

fileDir = os.path.dirname(os.path.realpath('mozgalo_gladbach_eintracht_akcije.csv'))
filename = os.path.join(fileDir, '../data/clean/mozgalo_gladbach_eintracht_akcije.csv')
file = os.path.abspath(os.path.realpath(filename))
dataframe = pd.read_csv(file)
refPositionX = dataframe["refPositionX"]
x = np.array(refPositionX)

mean = np.mean(x)
median = np.median(x)
std_dev = np.std(x)
mode = stats.mode(x)

print("Srednja vrijednost: %s" % mean)
print("Medijan: %s" % median)
print("Standardna devijacija: %s" % std_dev)
print("Mod: %s" % mode[0], "Koliko puta se ta vrijednost pojavila: %s" % mode[1])
# Out:
# Srednja vrijednost: 11.3601399099
# Medijan: 0.0
# Standardna devijacija: 90.3033389373
# Mod: [0] Koliko puta se ta vrijednost pojavila: [69135]

# %% [markdown]
# ## 'refPositionY' iz akcije.csv

# %%
import pandas as pd
import numpy as np
from scipy import stats
import os

fileDir = os.path.dirname(os.path.realpath('mozgalo_gladbach_eintracht_akcije.csv'))
filename = os.path.join(fileDir, '../data/clean/mozgalo_gladbach_eintracht_akcije.csv')
file = os.path.abspath(os.path.realpath(filename))
dataframe = pd.read_csv(file)
refPositionY = dataframe["refPositionY"]
y = np.array(refPositionY)

mean = np.mean(y)
median = np.median(y)
std_dev = np.std(y)
mode = stats.mode(y)

print("Srednja vrijednost: %s" % mean)
print("Medijan: %s" % median)
print("Standardna devijacija: %s" % std_dev)
print("Mod: %s" % mode[0], "Koliko puta se ta vrijednost pojavila: %s" % mode[1])
# Out:
# Srednja vrijednost: 7.0427794287
# Medijan: 0.0
# Standardna devijacija: 55.6542644678
# Mod: [ 0.] Koliko puta se ta vrijednost pojavila: [69135]

# %% [markdown]
# ## 'startPossTime' iz akcije.csv

# %% [markdown]
# Najviše se pojavljuje 0 kao vrijeme početka posjeda lopte. Ali pod action ID su najčešće za takve redove vrijednosti 212 što je
# zamjena igrača u tekmi.

# %%
import pandas as pd
import numpy as np
from scipy import stats
import os

fileDir = os.path.dirname(os.path.realpath('mozgalo_gladbach_eintracht_akcije.csv'))
filename = os.path.join(fileDir, '../data/clean/mozgalo_gladbach_eintracht_akcije.csv')
file = os.path.abspath(os.path.realpath(filename))
dataframe = pd.read_csv(file)
startPossTime = dataframe["startPossTime"]
startarray = np.array(startPossTime)

mean = np.mean(startarray)
median = np.median(startarray)
std_dev = np.std(startarray)
mode = stats.mode(startarray)

print("Srednja vrijednost: %s" % mean)
print("Medijan: %s" % median)
print("Standardna devijacija: %s" % std_dev)
print("Mod: %s" % mode[0], "Koliko puta se ta vrijednost pojavila: %s" % mode[1])
# Out:
# Srednja vrijednost: 2691.08169452
# Medijan: 2702.05
# Standardna devijacija: 1606.19460174
# Mod: [ 0.] Koliko puta se ta vrijednost pojavila: [182]

# %% [markdown]
# ## 'endPossTime' iz akcije.csv

# %% [markdown]
# Vidimo da ima više redova gdje je startPossTime 0 od redove gdje je endPossTime 0. Znači da postoje redovi gdje je startPossTime 0, a endPossTime neki broj.

# %%
import pandas as pd
import numpy as np
from scipy import stats
import os

fileDir = os.path.dirname(os.path.realpath('mozgalo_gladbach_eintracht_akcije.csv'))
filename = os.path.join(fileDir, '../data/clean/mozgalo_gladbach_eintracht_akcije.csv')
file = os.path.abspath(os.path.realpath(filename))
dataframe = pd.read_csv(file)
endPossTime = dataframe["endPossTime"]
endarray = np.array(endPossTime)

mean = np.mean(endarray)
median = np.median(endarray)
std_dev = np.std(endarray)
mode = stats.mode(endarray)

print("Srednja vrijednost: %s" % mean)
print("Medijan: %s" % median)
print("Standardna devijacija: %s" % std_dev)
print("Mod: %s" % mode[0], "Koliko puta se ta vrijednost pojavila: %s" % mode[1])
# Out:
# Srednja vrijednost: 2692.23273075
# Medijan: 2703.22
# Standardna devijacija: 1606.18980845
# Mod: [ 0.] Koliko puta se ta vrijednost pojavila: [171]

# %% [markdown]
# Provjera koji su to redovi gdje je startPossTime 0, a endPossTime neki broj. Ali to je ok, to su sve nove tekme na samom početku.

# %%
fileDir = os.path.dirname(os.path.realpath('mozgalo_gladbach_eintracht_akcije.csv'))
filename = os.path.join(fileDir, '../data/clean/mozgalo_gladbach_eintracht_akcije.csv')
file = os.path.abspath(os.path.realpath(filename))

fileakcije = open(file, "r")

for line in fileakcije:
    fields = line.split(",")
    if((fields[19] == '0') and (fields[20] != '0')):
        print(fields[0], fields[1])
# Out:
# 6256994 6258
# 6257304 6261
# 6370235 6364
# 6429196 6403
# 6466467 6425
# 6493833 6450
# 6599049 6553
# 6668837 6609
# 6761623 6681
# 6764773 6685
# 6823515 6730

# %% [markdown]
# Ovi redovi imaju actionStartTime i actioEndTime negativne brojeve. To ne znamo kaj znači.

# %%
fileDir = os.path.dirname(os.path.realpath('mozgalo_gladbach_eintracht_akcije.csv'))
filename = os.path.join(fileDir, '../data/clean/mozgalo_gladbach_eintracht_akcije.csv')
file = os.path.abspath(os.path.realpath(filename))

fileakcije = open(file, "r")
next(fileakcije)
for line in fileakcije:
    fields = line.split(",")
    if((float(fields[2]) < 0) and (float(fields[3]) < 0)):
        print(fields[0], fields[1])

# %% [markdown]
# Provjera da li ima ima akcija pod IDem 22 (prekid igre), a da nije zabilježena pozicija suca. Ako ne postoje akcije tipa 22 i da nije zabilježena pozicija suca, onda smo potvrdili ovo gore napisano.
#
# Postoje 34 akcije u kojima je prekinuta igra, od suca valjda, ali pozicija suca nije zabilježena. Ali to je valjda zbog opcije akcije, npr akcija id 359 - UKAZIVANJE POMOĆI, to valjda znači da je zabilježena pozicija suca samo onda kad je prekid igre (actionID 22), a prekid je zbog prekršaja na drugome igraču.

# %%
fileDir = os.path.dirname(os.path.realpath('mozgalo_gladbach_eintracht_akcije.csv'))
filename = os.path.join(fileDir, '../data/clean/mozgalo_gladbach_eintracht_akcije.csv')
file = os.path.abspath(os.path.realpath(filename))

lista = []
lista2 = []
fileakcije = open(file, "r")

for line in fileakcije:
    fields = line.split(",")
    if((fields[4] == '22') and (fields[17] == '0') and (fields[18] == '0')):
        lista.append(fields[0])
    if((fields[4] == '21') and (fields[17] == '0') and (fields[18] == '0')):
        lista2.append(fields[0])
        
print(len(lista))#ne postoje akcije di je prekinuta igra i da nije zabilježena pozicija suca
print(len(lista2))#prekid igre, ali sa drugacijom opcijom akcije, npr. ukazivanje pomoći
# Out:
# 0
# 34

# %% [markdown]
# Provjera koordinata početka i kraja akcija, da vidimo jel koja akcija ima koordinatu u ishodištu.
# ActionID 212 je zamjena i tamo koordinate
# i jesu nule.

# %%
fileDir = os.path.dirname(os.path.realpath('mozgalo_gladbach_eintracht_akcije.csv'))
filename = os.path.join(fileDir, '../data/clean/mozgalo_gladbach_eintracht_akcije.csv')
file = os.path.abspath(os.path.realpath(filename))


lista = []
lista2 = []
fileakcije = open(file, "r")

for line in fileakcije:
    fields = line.split(",")
    if(((fields[10] == '0') | (fields[12] == '0')) & (fields[4] != '212')):
        lista.append(fields[0])
        print(fields[0])
        
print(len(lista))
# Out:
# 6313431
# 6773506
# 2

# %% [markdown]
# Akcije gdje su koordinate x2 i y2 0, a akcija nije zaleđe niti zamjena igrača. Ovih 5 akcija su neke druge akcije koje opet pašu po tome da je samo jedna točka pozicije zabilježena.

# %%
fileDir = os.path.dirname(os.path.realpath('mozgalo_gladbach_eintracht_akcije.csv'))
filename = os.path.join(fileDir, '../data/clean/mozgalo_gladbach_eintracht_akcije.csv')
file = os.path.abspath(os.path.realpath(filename))

lista2 = []
fileakcije = open(file, "r")

for line in fileakcije:
    fields = line.split(",")
    if(((fields[11] == '0') | (fields[13] == '0'))  & (fields[4] != '7') & (fields[4] != '212')):
        lista2.append(fields[0])
        print(fields[0])
        
print(len(lista2))
# Out:
# 6381572
# 6723994
# 6726432
# 6773506
# 6775555
# 5

# %% [markdown]
# Akcije gdje su actionID i actionOptionID jednaki. To su uglavnom klizeći startovi (actionID 11). To je ok.

# %%
fileDir = os.path.dirname(os.path.realpath('mozgalo_gladbach_eintracht_akcije.csv'))
filename = os.path.join(fileDir, '../data/clean/mozgalo_gladbach_eintracht_akcije.csv')
file = os.path.abspath(os.path.realpath(filename))

lista2 = []
fileakcije = open(file, "r")

for line in fileakcije:
    fields = line.split(",")
    if(fields[4] == fields[6]):
        lista2.append(fields[0])
        print(fields[0])
        
print(len(lista2))
# Out:
# 6257245
# 6257471
# 6257707
# 6258002
# 6258418
# 6259571
# 6259592
# 6261341
# 6264488
# 6266290
# 6266519
# 6268280
# 6305525
# 6305630
# 6306414
# 6307179
# 6307393
# 6308866
# 6309709
# 6310200
# 6310907
# 6312128
# 6312626
# 6313261
# 6313336
# 6315225
# 6343949
# 6344050
# 6344292
# 6344540
# 6344766
# 6344906
# 6345648
# 6345871
# 6346320
# 6346324
# 6346403
# 6346594
# 6346862
# 6347659
# 6347703
# 6370557
# 6371796
# 6372825
# 6373844
# 6374202
# 6374465
# 6376135
# 6376498
# 6377008
# 6378038
# 6378422
# 6378773
# 6379221
# 6379254
# 6379917
# 6380776
# 6381564
# 6381884
# 6401649
# 6401861
# 6402821
# 6409151
# 6409396
# 6424442
# 6424890
# 6426898
# 6427322
# 6429881
# 6430287
# 6430481
# 6430910
# 6431237
# 6431639
# 6431701
# 6431927
# 6432006
# 6432308
# 6433322
# 6433759
# 6434074
# 6455433
# 6457886
# 6458896
# 6461317
# 6461730
# 6461901
# 6461960
# 6467794
# 6469053
# 6469070
# 6470523
# 6470784
# 6470855
# 6470876
# 6471550
# 6471893
# 6472118
# 6472157
# 6495680
# 6499386
# 6502569
# 6503732
# 6504718
# 6504945
# 6506190
# 6506525
# 6506768
# 6512584
# 6579509
# 6599473
# 6600603
# 6600928
# 6603579
# 6604348
# 6604545
# 6605312
# 6625587
# 6632643
# 6633246
# 6633884
# 6634451
# 6634520
# 6638750
# 6638775
# 6640125
# 6640829
# 6641176
# 6642744
# 6666511
# 6682075
# 6720172
# 6722259
# 6722576
# 6722960
# 6723417
# 6727240
# 6761653
# 6761710
# 6762058
# 6762134
# 6762264
# 6762293
# 6762843
# 6762940
# 6763389
# 6763544
# 6763582
# 6763879
# 6763952
# 6772327
# 6773423
# 6774896
# 6820867
# 6824467
# 6826204
# 6827322
# 6827408
# 6828313
# 6830242
# 6830435
# 6830454
# 6830758
# 6856992
# 6857896
# 6859250
# 6859394
# 6859413
# 6859801
# 6861580
# 6862220
# 6866948
# 6868386
# 6868929
# 6880329
# 6880344
# 6880762
# 6881986
# 6883400
# 6884685
# 6886464
# 6889677
# 6890821
# 6892086
# 6893349
# 6895545
# 186

# %%
fileDir = os.path.dirname(os.path.realpath('mozgalo_gladbach_eintracht_akcije.csv'))
filename = os.path.join(fileDir, '../data/clean/mozgalo_gladbach_eintracht_akcije.csv')
file = os.path.abspath(os.path.realpath(filename))

lista2 = []
fileakcije = open(file, "r")

for line in fileakcije:
    fields = line.split(",")
    if(fields[7] == fields[14]):
        lista2.append(fields[0])
        print(fields[0])
        
print(len(lista2))
# Out:
# 6257040
# 6257067
# 6257123
# 6257530
# 6257936
# 6258631
# 6258690
# 6258820
# 6259117
# 6259222
# 6259366
# 6259430
# 6259710
# 6259810
# 6259885
# 6260011
# 6260177
# 6260274
# 6260521
# 6260775
# 6260988
# 6261679
# 6261839
# 6262544
# 6262591
# 6262876
# 6263327
# 6263555
# 6263638
# 6263703
# 6263901
# 6263940
# 6264221
# 6264817
# 6264856
# 6264920
# 6264937
# 6265114
# 6265575
# 6266349
# 6267167
# 6267503
# 6267800
# 6267873
# 6268364
# 6268639
# 6268942
# 6269026
# 6304901
# 6305098
# 6305184
# 6305735
# 6306043
# 6306981
# 6307022
# 6307287
# 6307410
# 6309481
# 6309546
# 6310080
# 6310234
# 6310560
# 6310654
# 6311095
# 6311364
# 6311365
# 6311369
# 6311969
# 6313021
# 6313028
# 6313047
# 6313625
# 6314092
# 6314104
# 6314496
# 6314901
# 6314929
# 6315167
# 6315391
# 6315409
# 6315924
# 6316045
# 6316176
# 6316498
# 6316713
# 6317369
# 6317371
# 6317372
# 6344405
# 6344532
# 6344557
# 6344558
# 6344573
# 6344681
# 6345511
# 6345686
# 6345687
# 6345775
# 6345977
# 6346103
# 6346202
# 6346263
# 6346304
# 6346425
# 6346981
# 6347339
# 6347508
# 6347635
# 6347742
# 6347767
# 6347794
# 6370921
# 6371603
# 6372303
# 6372383
# 6372386
# 6372513
# 6372516
# 6372726
# 6373849
# 6374135
# 6374969
# 6375549
# 6375909
# 6376310
# 6377138
# 6377153
# 6377156
# 6377527
# 6377894
# 6378112
# 6378114
# 6378115
# 6378116
# 6378642
# 6378723
# 6379024
# 6379287
# 6379329
# 6380100
# 6380419
# 6381138
# 6381181
# 6381514
# 6381630
# 6382115
# 6382180
# 6382182
# 6382201
# 6382212
# 6382233
# 6382234
# 6382337
# 6382390
# 6382653
# 6382654
# 6382739
# 6382740
# 6382769
# 6382826
# 6382833
# 6401562
# 6401582
# 6401656
# 6401718
# 6401784
# 6401823
# 6402034
# 6402324
# 6403178
# 6403215
# 6403868
# 6404001
# 6404131
# 6404301
# 6404795
# 6404956
# 6406062
# 6406208
# 6408977
# 6408980
# 6409988
# 6410088
# 6410147
# 6410378
# 6410447
# 6410604
# 6410794
# 6423799
# 6424013
# 6424017
# 6424319
# 6424779
# 6425444
# 6426205
# 6426603
# 6426624
# 6426633
# 6426788
# 6426798
# 6426840
# 6426908
# 6427047
# 6427162
# 6427183
# 6429242
# 6429538
# 6429539
# 6429613
# 6429812
# 6430803
# 6430820
# 6431085
# 6431275
# 6431359
# 6432344
# 6432731
# 6433084
# 6433173
# 6433426
# 6433633
# 6433634
# 6434011
# 6434012
# 6454089
# 6454092
# 6454515
# 6455580
# 6455997
# 6456486
# 6457003
# 6458688
# 6458862
# 6459531
# 6459635
# 6460023
# 6461376
# 6461744
# 6461745
# 6461784
# 6461918
# 6461941
# 6462325
# 6462362
# 6462389
# 6462451
# 6462452
# 6462545
# 6462605
# 6462606
# 6462748
# 6466645
# 6467357
# 6467410
# 6467493
# 6467514
# 6467841
# 6468645
# 6468727
# 6468842
# 6468843
# 6469441
# 6469876
# 6469881
# 6470208
# 6471277
# 6471530
# 6471540
# 6471541
# 6471757
# 6471920
# 6471943
# 6493903
# 6494242
# 6495241
# 6495491
# 6495741
# 6495902
# 6495994
# 6496328
# 6496494
# 6497822
# 6498178
# 6498247
# 6499993
# 6500822
# 6501063
# 6501107
# 6501602
# 6501877
# 6501962
# 6502869
# 6502908
# 6503073
# 6503182
# 6503769
# 6505140
# 6505484
# 6505507
# 6505686
# 6505729
# 6505761
# 6505762
# 6506277
# 6506321
# 6511529
# 6511580
# 6511715
# 6511740
# 6511756
# 6511842
# 6511855
# 6512480
# 6512481
# 6512511
# 6512744
# 6512812
# 6512857
# 6512863
# 6512864
# 6512883
# 6512887
# 6512974
# 6513029
# 6513117
# 6513134
# 6513171
# 6513175
# 6513247
# 6513276
# 6513351
# 6513491
# 6513513
# 6513514
# 6513523
# 6513646
# 6513753
# 6513798
# 6513832
# 6513844
# 6513845
# 6513848
# 6580308
# 6580446
# 6580765
# 6580780
# 6580912
# 6580986
# 6582027
# 6582146
# 6582353
# 6582433
# 6582565
# 6582926
# 6582929
# 6584014
# 6585348
# 6585369
# 6585951
# 6586096
# 6586796
# 6586877
# 6586908
# 6587200
# 6587636
# 6589525
# 6589543
# 6599272
# 6599273
# 6599591
# 6599988
# 6600979
# 6601044
# 6601045
# 6601529
# 6601665
# 6601702
# 6601989
# 6601999
# 6602057
# 6602158
# 6602642
# 6602898
# 6602901
# 6602936
# 6603037
# 6603145
# 6603369
# 6603543
# 6603785
# 6604309
# 6605135
# 6605137
# 6605143
# 6624097
# 6624327
# 6624354
# 6624606
# 6624954
# 6625096
# 6625097
# 6625098
# 6625143
# 6625661
# 6625926
# 6626549
# 6626742
# 6626763
# 6627230
# 6627233
# 6628288
# 6628518
# 6628519
# 6631164
# 6631660
# 6631700
# 6632336
# 6632483
# 6633170
# 6633977
# 6635173
# 6635876
# 6636089
# 6637177
# 6637843
# 6637932
# 6638401
# 6639532
# 6640979
# 6641975
# 6642872
# 6666295
# 6666329
# 6666335
# 6666365
# 6666366
# 6666408
# 6666447
# 6666662
# 6666764
# 6666844
# 6666922
# 6666923
# 6666948
# 6666949
# 6666978
# 6666979
# 6667043
# 6667141
# 6667157
# 6667211
# 6667219
# 6667306
# 6667338
# 6667349
# 6667358
# 6667359
# 6667506
# 6667524
# 6667576
# 6667723
# 6667724
# 6667854
# 6667899
# 6668078
# 6668079
# 6668451
# 6668604
# 6669525
# 6670108
# 6670197
# 6670415
# 6670498
# 6671338
# 6671391
# 6671917
# 6672113
# 6672559
# 6673474
# 6673529
# 6673750
# 6673861
# 6673864
# 6673894
# 6674073
# 6676636
# 6676644
# 6677115
# 6678130
# 6678133
# 6678391
# 6678439
# 6678847
# 6678853
# 6679737
# 6679993
# 6679999
# 6681734
# 6682046
# 6719805
# 6719935
# 6719990
# 6720240
# 6720278
# 6720521
# 6720688
# 6720815
# 6720860
# 6720864
# 6720882
# 6720960
# 6721006
# 6721229
# 6721231
# 6721294
# 6721619
# 6721844
# 6721952
# 6722295
# 6722297
# 6722328
# 6722397
# 6722481
# 6722597
# 6722695
# 6722764
# 6722829
# 6723027
# 6723029
# 6723101
# 6723137
# 6723325
# 6723456
# 6724141
# 6724243
# 6724522
# 6724951
# 6725097
# 6726203
# 6726204
# 6726205
# 6726432
# 6726584
# 6726789
# 6726790
# 6727285
# 6728794
# 6729346
# 6729348
# 6761829
# 6761900
# 6761952
# 6761985
# 6762219
# 6762220
# 6762246
# 6762306
# 6762307
# 6762463
# 6762588
# 6762682
# 6762758
# 6762849
# 6762879
# 6762982
# 6763101
# 6763256
# 6763261
# 6763291
# 6763354
# 6763417
# 6763418
# 6763562
# 6764034
# 6764035
# 6764036
# 6764171
# 6764199
# 6765786
# 6765790
# 6766073
# 6770791
# 6772594
# 6773253
# 6773685
# 6774720
# 6774773
# 6774790
# 6775555
# 6775993
# 6776129
# 6776463
# 6820765
# 6821020
# 6822578
# 6823195
# 6823865
# 6824057
# 6824468
# 6824493
# 6825037
# 6825232
# 6825887
# 6826301
# 6826431
# 6826742
# 6826925
# 6826966
# 6827034
# 6827148
# 6828181
# 6828627
# 6828744
# 6829019
# 6829179
# 6829791
# 6829935
# 6829944
# 6830103
# 6830113
# 6830383
# 6830478
# 6830514
# 6830524
# 6830536
# 6830546
# 6830547
# 6830672
# 6830683
# 6830812
# 6830850
# 6830958
# 6830984
# 6830985
# 6831009
# 6857750
# 6857751
# 6858265
# 6858317
# 6859002
# 6859259
# 6859306
# 6859455
# 6860547
# 6860554
# 6860906
# 6861298
# 6861301
# 6861609
# 6861614
# 6861682
# 6861882
# 6862012
# 6862015
# 6862049
# 6862393
# 6862917
# 6863036
# 6863259
# 6863318
# 6863335
# 6863336
# 6863373
# 6863427
# 6863492
# 6863625
# 6864217
# 6864398
# 6864574
# 6864618
# 6864687
# 6864712
# 6864714
# 6865221
# 6865527
# 6865804
# 6866699
# 6866705
# 6866785
# 6866836
# 6866847
# 6866994
# 6867136
# 6867141
# 6867255
# 6867354
# 6867431
# 6867565
# 6868081
# 6868131
# 6868150
# 6868495
# 6868521
# 6868522
# 6868653
# 6868896
# 6868980
# 6868982
# 6869015
# 6869109
# 6869196
# 6869533
# 6869535
# 6869731
# 6869783
# 6869911
# 6870189
# 6870194
# 6870218
# 6880332
# 6880702
# 6881496
# 6881668
# 6881691
# 6882015
# 6882082
# 6882156
# 6882191
# 6882282
# 6882367
# 6882403
# 6882576
# 6882701
# 6883053
# 6883277
# 6883279
# 6883280
# 6883889
# 6884135
# 6884314
# 6884470
# 6884630
# 6884711
# 6884825
# 6884828
# 6885412
# 6885462
# 6886903
# 6887160
# 6887934
# 6888047
# 6888051
# 6888085
# 6888242
# 6888247
# 6888677
# 6888990
# 6889000
# 6889001
# 6889150
# 6889332
# 6889430
# 6889483
# 6889560
# 6891316
# 6891801
# 6892033
# 6892192
# 6892894
# 6893661
# 6893887
# 6894303
# 6894983
# 6895128
# 6895382
# 765

# %% [markdown]
# Provjera koliko žutih kartona je podijeljeno u utakmicama domaćim ekipama.

# %%
fileDir = os.path.dirname(os.path.realpath('mozgalo_gladbach_eintracht_akcije.csv'))
filename = os.path.join(fileDir, '../data/clean/mozgalo_gladbach_eintracht_akcije.csv')
file = os.path.abspath(os.path.realpath(filename))

lista2 = []
fileakcije = open(file, "r")

for line in fileakcije:
    fields = line.split(",")
    if((fields[6] == '210') & (fields[9] == 'home')):
        lista2.append(fields[0])
        print(fields[0])
        
print(len(lista2))
# Out:
# 6260226
# 6263327
# 6268255
# 6311969
# 6314929
# 6315391
# 6346202
# 6347635
# 6370921
# 6377156
# 6382182
# 6382234
# 6382654
# 6382833
# 6408977
# 6426205
# 6426782
# 6426798
# 6427372
# 6495902
# 6501602
# 6505729
# 6512857
# 6586796
# 6602898
# 6605143
# 6637932
# 6638401
# 6667043
# 6673864
# 6678391
# 6720882
# 6721953
# 6725097
# 6728794
# 6729348
# 6763418
# 6764036
# 6770641
# 6774162
# 6831009
# 6858265
# 6863427
# 6865527
# 6870189
# 6884470
# 6886502
# 6888051
# 6888677
# 6889430
# 6893531
# 6896173
# 52

# %%
fileDir = os.path.dirname(os.path.realpath('mozgalo_gladbach_eintracht_akcije.csv'))
filename = os.path.join(fileDir, '../data/clean/mozgalo_gladbach_eintracht_akcije.csv')
file = os.path.abspath(os.path.realpath(filename))

lista2 = []
fileakcije = open(file, "r")

for line in fileakcije:
    fields = line.split(",")
    if((fields[6] == '68') & (fields[9] == 'away')):
        lista2.append(fields[0])
        print(fields[0])
        
print(len(lista2))
# Out:
# 6381514
# 6469881
# 6678853
# 6894573
# 4
