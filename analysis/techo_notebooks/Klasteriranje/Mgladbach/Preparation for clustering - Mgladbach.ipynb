# %%
import numpy as np
import seaborn as sns
import pandas as pd
from pandas import Series,DataFrame
import os

igraci = [16087, 206309, 11341, 11500, 16894, 4610, 39479, 205485, 205180, 102647, 156709, 115078, 126631, 16491, 127794, 185121,
          175582, 206094, 101192, 16901, 65256, 4613, 66692]

dfAkcije = pd.read_csv("mozgalo_gladbach_eintracht_akcije_spojeno.csv", sep = ',')
dfMgladbachUkupno = dfAkcije[dfAkcije['playerID'].isin(igraci)]
dfMgladbachUkupno.to_csv("Mgladbach_za_klasteriranje.csv", sep=',', index=False)
dfMgladbachUkupno
# Out:
#             ID  gameID  actionStartTime  actionEndTime  actionID  \
# 2199   6257304    6261             0.00           0.20       247
# 2200   6257310    6261             0.20           1.61       247
# 2201   6257313    6261             1.61           6.70       232
# 2202   6257318    6261             1.61           6.70        19
# 2208   6257381    6261            44.66          47.05       248
# 2209   6257385    6261            44.66          47.05        19
# 2210   6257390    6261            44.66          47.05       211
# 2213   6257399    6261            48.42          49.75       248
# 2216   6257430    6261            53.89          55.28        13
# 2217   6257432    6261            53.89          55.28       211
# 2218   6257437    6261            53.89          55.28        17
# 2221   6257520    6261            86.79          90.83        13
# 2222   6257521    6261            86.79          90.83       211
# ...
