# %% [markdown]
# # Vizualizacija bitnih akcija iz klastera 0 i 1

# %% [markdown]
# Učitavanje .csv filea u dataframe

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

dfSek13i16 = pd.read_csv("Mgladbach_centarsutevi_sek13i16.csv", sep = ',')
dfSek13i16
# Out:
#            ID           actionIDNaziv        actionOptionIDN  playerID  \
# 0     6257520                  KORNER       IZGUBLJEN KORNER     39479
# 1     6257521         NIJE IZGUBLJENA                 KORNER     39479
# 2     6257631         TOCNO DODAVANJE                      0      4610
# 3     6257675         TOCNO DODAVANJE                      0     66692
# 4     6258055         TOCNO DODAVANJE                      0     66692
# 5     6258058        OSTALA DODAVANJA                 GLAVOM     66692
# 6     6258209         TOCNO DODAVANJE                      0     66692
# 7     6258211          LOPTA PO ZRAKU        TOCNO DODAVANJE     66692
# 8     6258409         TOCNO DODAVANJE                      0      4610
# 9     6258450       NETOCNO DODAVANJE                      0     66692
# 10    6258923                     OUT          IZGUBLJEN OUT     11341
# 11    6258925     ISPUCAVANJE NETOCNO                    OUT     11341
# ...

# %% [markdown]
# Vizualizacija početka i kraja centaršuteva iz sektora 13 i 16

# %%
dfDoma = dfSek13i16[dfSek13i16['domaci'] == 'Borussia Mgladbach']
dfGosti = dfSek13i16[dfSek13i16['gosti'] == 'Borussia Mgladbach']

dfx1Doma = dfDoma['actionPosX1']
dfy1Doma = dfDoma['actionPosY1']
dfx2Doma = dfDoma['actionPosX2']
dfy2Doma = dfDoma['actionPosY2']

dfx1Gosti = dfGosti['actionPosX1']
dfy1Gosti = dfGosti['actionPosY1']
dfx2Gosti = dfGosti['actionPosX2']
dfy2Gosti = dfGosti['actionPosY2']

fig = plt.figure(figsize = (12, 24))
fig.clf()
ax1 = fig.add_subplot(1,1,1)
ax2 = fig.add_subplot(1,1,1)
ax3 = fig.add_subplot(1,1,1)
ax4 = fig.add_subplot(1,1,1)

plt.plot([dfx1Doma, dfx2Doma], [dfy1Doma, dfy2Doma], c='black')
plt.plot([dfx1Gosti, dfx2Gosti], [dfy1Gosti, dfy2Gosti], c='black')
plt.yticks([0,225,450,675,900])
plt.xticks([0,350,700,1050,1400])
im = plt.imread('igraliste2.png')
ax1.scatter(dfx1Doma, dfy1Doma, s=60, zorder=1, c='b', label='Početak doma')
ax2.scatter(dfx2Doma, dfy2Doma, s=60, zorder=1, c='y', label='Kraj doma')
ax3.scatter(dfx1Gosti, dfy1Gosti, s=60, zorder=1, c='r', label='Početak gosti')
ax4.scatter(dfx2Gosti, dfy2Gosti, s=60, zorder=1, c='c', label='Kraj gosti')

implot = plt.imshow(im, zorder=0, extent=[0, 1400, 900, 0])
plt.xlabel('actionPosX')
plt.ylabel('actionPosY')
plt.title('Lokacije početka i kraja centaršutova prema koordinatama - Mgladbach sektor 13 i 16')

def label_point(x, y, val, ax):
    a = pd.concat({'x': x, 'y': y, 'val': val}, axis=1)
    for i, point in a.iterrows():
        ax.text(point['x'], point['y'], str(point['val']))

label_point(dfSek13i16.actionPosX1, dfSek13i16.actionPosY1, dfSek13i16.name, ax1)
label_point(dfSek13i16.actionPosX1, dfSek13i16.actionPosY1, dfSek13i16.name, ax1)

plt.legend()
plt.show()

# %% [markdown]
# # Vizualizacija početka i kraja svih centaršuteva

# %%
dfSveM = pd.read_csv("Mgladbach_sve_akcije.csv", sep = ',')
dfSveM
# Out:
#             ID  gameID  actionStartTime  actionEndTime  actionID  \
# 0      6257304    6261             0.00           0.20       247
# 1      6257310    6261             0.20           1.61       247
# 2      6257313    6261             1.61           6.70       232
# 3      6257318    6261             1.61           6.70        19
# 4      6257381    6261            44.66          47.05       248
# 5      6257385    6261            44.66          47.05        19
# 6      6257390    6261            44.66          47.05       211
# 7      6257399    6261            48.42          49.75       248
# 8      6257430    6261            53.89          55.28        13
# 9      6257432    6261            53.89          55.28       211
# 10     6257437    6261            53.89          55.28        17
# 11     6257520    6261            86.79          90.83        13
# 12     6257521    6261            86.79          90.83       211
# ...

# %% [markdown]
# Vizualizacija svih centaršuteva za Mgladbach

# %%
dfCentarsutevi = dfSveM[dfSveM['actionIDNaziv'] == 'CENTARSUT']
dfCentarsuteviFiltered = dfCentarsutevi[['ID', 'actionIDNaziv', 'actionOptionIDN', 'playerID', 'actionPosX1', 'actionPosY1', 
                                         'actionPosX2', 'actionPosY2', 'domaci', 'gosti']]

dfDoma = dfCentarsuteviFiltered[dfCentarsuteviFiltered['domaci'] == 'Borussia Mgladbach']
dfGosti = dfCentarsuteviFiltered[dfCentarsuteviFiltered['gosti'] == 'Borussia Mgladbach']

dfx1Doma = dfDoma['actionPosX1']
dfy1Doma = dfDoma['actionPosY1']
dfx2Doma = dfDoma['actionPosX2']
dfy2Doma = dfDoma['actionPosY2']

dfx1Gosti = dfGosti['actionPosX1']
dfy1Gosti = dfGosti['actionPosY1']
dfx2Gosti = dfGosti['actionPosX2']
dfy2Gosti = dfGosti['actionPosY2']

fig = plt.figure(figsize = (12, 24))
fig.clf()
ax1 = fig.add_subplot(1,1,1)
ax2 = fig.add_subplot(1,1,1)
ax3 = fig.add_subplot(1,1,1)
ax4 = fig.add_subplot(1,1,1)

plt.plot([dfx1Doma, dfx2Doma], [dfy1Doma, dfy2Doma], c='black')
plt.plot([dfx1Gosti, dfx2Gosti], [dfy1Gosti, dfy2Gosti], c='black')
plt.yticks([0,225,450,675,900])
plt.xticks([0,350,700,1050,1400])
im = plt.imread('igraliste2.png')
ax1.scatter(dfx1Doma, dfy1Doma, s=60, zorder=1, c='b', label='Početak doma')
ax2.scatter(dfx2Doma, dfy2Doma, s=60, zorder=1, c='y', label='Kraj doma')
ax3.scatter(dfx1Gosti, dfy1Gosti, s=60, zorder=1, c='r', label='Početak gosti')
ax4.scatter(dfx2Gosti, dfy2Gosti, s=60, zorder=1, c='c', label='Kraj gosti')

implot = plt.imshow(im, zorder=0, extent=[0, 1400, 900, 0])
plt.xlabel('actionPosX')
plt.ylabel('actionPosY')
plt.title('Lokacije početka i kraja centaršutova prema koordinatama - Mgladbach ukupno')

plt.legend(loc='upper center')
plt.show()

# %% [markdown]
# Vizualizacija svih udaraca Mgladbacha iz sektora 5. Prvo učitajmo sve podatke.

# %%
dfUdarci = pd.read_csv("Mgladbach_udarci_sek5.csv", sep = ',')
dfUdarci
# Out:
#           ID actionIDNaziv actionOptionIDN  playerID  actionPosX1  \
# 0    6269058        UDARAC        PO ZRAKU    156709          172
# 1    6269059        UDARAC      DESNA NOGA    156709          172
# 2    6269097        UDARAC      DESNA NOGA    156709          104
# 3    6269098        UDARAC             LOS    156709          104
# 4    6313958        UDARAC   UDARAC U BLOK     16491          251
# 5    6313961        UDARAC     LIJEVA NOGA     16491          251
# 6    6313966        UDARAC       PO ZEMLJI     16491          251
# 7    6314305        UDARAC        PO ZRAKU     39479          129
# 8    6314306        UDARAC          GLAVOM     39479          129
# 9    6315325        UDARAC        PO ZRAKU     16087          254
# 10   6315327        UDARAC      DESNA NOGA     16087          254
# 11   6315329        UDARAC            ZONA     16087          254
# 12   6315558        UDARAC       PO ZEMLJI     11500          307
# ...

# %% [markdown]
# Vizualizacija svih udaraca Mgladbacha iz sektora 5.

# %%
dfDoma = dfUdarci[dfUdarci['domaci'] == 'Borussia Mgladbach']
dfGosti = dfUdarci[dfUdarci['gosti'] == 'Borussia Mgladbach']

dfx1Doma = dfDoma['actionPosX1']
dfy1Doma = dfDoma['actionPosY1']


dfx1Gosti = dfGosti['actionPosX1']
dfy1Gosti = dfGosti['actionPosY1']


fig = plt.figure(figsize = (12, 24))
fig.clf()
ax1 = fig.add_subplot(1,1,1)
ax2 = fig.add_subplot(1,1,1)


plt.yticks([0,225,450,675,900])
plt.xticks([0,350,700,1050,1400])
im = plt.imread('igraliste2.png')
ax1.scatter(dfx1Doma, dfy1Doma, s=60, zorder=1, c='b', label='Početak doma')
ax2.scatter(dfx1Gosti, dfy1Gosti, s=60, zorder=1, c='y', label='Početak gosti')
implot = plt.imshow(im, zorder=0, extent=[0, 1400, 900, 0])
plt.xlabel('actionPosX')
plt.ylabel('actionPosY')
plt.title('Lokacije početka udaraca prema koordinatama - Mgladbach sektor 5')

plt.legend()
plt.show()

# %% [markdown]
# Vizualizacija svih udaraca Mgladbacha da vidimo usporedbu sa udarcima iz klastera 0.

# %%
dfUdarci1 = dfSveM[dfSveM['actionIDNaziv'] == 'UDARAC']
dfUdarciFiltered = dfUdarci1[['ID', 'actionIDNaziv', 'actionOptionIDN', 'bindedActionIDN' , 
                              'playerID', 'actionPosX1', 'actionPosY1', 
                                         'actionPosX2', 'actionPosY2', 'domaci', 'gosti']]

dfDoma = dfUdarciFiltered[dfUdarciFiltered['domaci'] == 'Borussia Mgladbach']
dfGosti = dfUdarciFiltered[dfUdarciFiltered['gosti'] == 'Borussia Mgladbach']

dfx1Doma = dfDoma['actionPosX1']
dfy1Doma = dfDoma['actionPosY1']


dfx1Gosti = dfGosti['actionPosX1']
dfy1Gosti = dfGosti['actionPosY1']


fig = plt.figure(figsize = (12, 24))
fig.clf()
ax1 = fig.add_subplot(1,1,1)
ax2 = fig.add_subplot(1,1,1)


plt.yticks([0,225,450,675,900])
plt.xticks([0,350,700,1050,1400])
im = plt.imread('igraliste2.png')
ax1.scatter(dfx1Doma, dfy1Doma, s=60, zorder=1, c='b', label='Početak doma')
ax2.scatter(dfx1Gosti, dfy1Gosti, s=60, zorder=1, c='y', label='Početak gosti')
implot = plt.imshow(im, zorder=0, extent=[0, 1400, 900, 0])
plt.xlabel('actionPosX')
plt.ylabel('actionPosY')
plt.title('Lokacije početka udaraca prema koordinatama - Mgladbach ukupno')

plt.legend()
plt.show()

# %% [markdown]
# Vizualizacija izgubljenih lopti u sektorima 5 i 1

# %%
dfIzgubljeneLopte = pd.read_csv("Mgladbach_izgubljene_lopte_sek5i1.csv", sep = ',')
dfIzgubljeneLopte
# Out:
#          ID     actionIDNaziv         actionOptionIDN  playerID  actionPosX1  \
# 0   6259309  IZGUBLJENA LOPTA   IZGUBLJENA U PRIMANJU    102647          342
# 1   6265520  IZGUBLJENA LOPTA  IZGUBLJENA U DRIBLINGU    115078          234
# 2   6266527  IZGUBLJENA LOPTA  IZGUBLJENA U DRIBLINGU     16491          232
# 3   6267799  IZGUBLJENA LOPTA  IZGUBLJENA U DRIBLINGU    115078          267
# 4   6268804  IZGUBLJENA LOPTA  IZGUBLJENA U DRIBLINGU     39479          339
# 5   6314915  IZGUBLJENA LOPTA   IZGUBLJENA U PRIMANJU    126631          161
# 6   6315912  IZGUBLJENA LOPTA   IZGUBLJENA U PRIMANJU     39479          199
# 7   6316610  IZGUBLJENA LOPTA  IZGUBLJENA U DRIBLINGU    126631          220
# 8   6346259  IZGUBLJENA LOPTA  IZGUBLJENA U DRIBLINGU    115078          340
# 9   6346396  IZGUBLJENA LOPTA  IZGUBLJENA U DRIBLINGU     16894          309
# 10  6375764  IZGUBLJENA LOPTA   IZGUBLJENA U PRIMANJU    115078          212
# ...

# %%
dfDoma = dfIzgubljeneLopte[dfIzgubljeneLopte['domaci'] == 'Borussia Mgladbach']
dfGosti = dfIzgubljeneLopte[dfIzgubljeneLopte['gosti'] == 'Borussia Mgladbach']

dfx1Doma = dfDoma['actionPosX1']
dfy1Doma = dfDoma['actionPosY1']


dfx1Gosti = dfGosti['actionPosX1']
dfy1Gosti = dfGosti['actionPosY1']


fig = plt.figure(figsize = (12, 24))
fig.clf()
ax1 = fig.add_subplot(1,1,1)
ax2 = fig.add_subplot(1,1,1)


plt.yticks([0,225,450,675,900])
plt.xticks([0,350,700,1050,1400])
im = plt.imread('igraliste2.png')
ax1.scatter(dfx1Doma, dfy1Doma, s=60, zorder=1, c='b', label='Početak doma')
ax2.scatter(dfx1Gosti, dfy1Gosti, s=60, zorder=1, c='y', label='Početak gosti')
implot = plt.imshow(im, zorder=0, extent=[0, 1400, 900, 0])
plt.xlabel('actionPosX')
plt.ylabel('actionPosY')
plt.title('Lokacije izgubljenih lopti - Mgladbach sektor 5 i 1')


plt.legend()
plt.show()
