# %% [markdown]
# # Vizualizacija bitnih akcija iz klastera 0 i 1

# %% [markdown]
# Učitavanje .csv filea u dataframe

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

#dfSek13i16 = pd.read_csv("Mgladbach_centarsutevi_sek13i16.csv", sep = ',')
#dfSek13i16

# %% [markdown]
# Vizualizacija početka i kraja centaršuteva iz sektora 13 i 16

# %% [markdown]
# # Vizualizacija početka i kraja svih centaršuteva

# %%
dframe_BM_FL_248 = pd.read_csv("dframe_BM_FL_248.csv", sep = ',')
dframe_BM_FL_248

dframe_EF_FL_248 = pd.read_csv("dframe_BM_FL_248.csv", sep = ',')
dframe_EF_FL_248
# Out:
#      Unnamed: 0  playerID  targetPlayerID  actionPosX1  actionPosX2  \
# 0             0     16087          198668          453          962
# 1             1     16087          102537          162          170
# 2             2     16087          204427          266          392
# 3             3     16087          196781          559          585
# 4             4     16087          196658          627         1236
# 5             5     16087          196781          553          679
# 6             6     16087           29434          630          747
# 7             7     16087           39381          668         1026
# 8             8     16087          136144          513          714
# 9             9     16087            5949          769         1224
# 10           10     16087           56968          514          403
# 11           11     16087           29485          347          310
# 12           12     16087           97021          481          772
# 13           13     16087          205987          759          840
# 14           14     16087           97021         1119         1162
# 15           15     16087           57544          248          242
# 16           16    206309           43159          813          846
# 17           17    206309           43159          714          729
# 18           18    206309          198668          490          637
# 19           19    206309          109708          800         1167
# 20           20    206309           43159          569          626
# 21           21    206309          198668          760          972
# 22           22    206309          204427          720          730
# 23           23    206309           54894          415          610
# 24           24    206309          136144          184          226
# 25           25    206309           54894          369          780
# 26           26    206309          123620          769         1018
# 27           27    206309          196781          493          635
# 28           28    206309           39466          862          994
# 29           29    206309           54894          427          533
# ..          ...       ...             ...          ...          ...
# 239         239     16491           39466          369          338
# 240         240     16491          136144          776          809
# 241         241     16491          123620          818          814
# 242         242     16491          196658         1044         1228
# 243         243     16491          102535          108          190
# 244         244    127794           39466          613          833
# 245         245    127794           39466          397          802
# 246         246    127794           39466          460          777
# 247         247    127794           29434          222          404
# 248         248    127794            1882          423         1134
# 249         249    127794           57544          674          893
# 250         250    127794           56968          331          514
# 251         251    127794           57544          547          646
# 252         252    127794           56968          600          605
# 253         253    127794           29485          499          415
# 254         254    127794          113769          475          950
# 255         255    127794           74560          497          694
# 256         256    127794           56968          510          525
# 257         257    127794            5949          761          917
# 258         258    127794          113769          480          959
# 259         259    127794          205987          594          736
# 260         260    185121          102535          823          749
# 261         261    185121           39466         1117         1120
# 262         262    185121           39381          807          887
# 263         263    185121           39466         1099         1118
# 264         264    185121          123620          887         1100
# 265         265    185121          156937          770          754
# 266         266    185121           39381         1211         1224
# 267         267    185121           39381         1213         1209
# 268         268    185121           39466          838          862
#
#      actionPosY1  actionPosY2
# 0         382.32       740.32
# 1         193.32       204.32
# 2         138.32       175.32
# 3         536.32       548.32
# 4         671.32       481.32
# 5         660.32       678.32
# 6         392.32       345.32
# 7         372.32       120.32
# 8         267.32       482.32
# 9         727.32       612.32
# 10        722.32       680.32
# 11        570.32       379.32
# 12        794.32       718.32
# 13        715.32       407.32
# 14        621.32       608.32
# 15        764.32       764.32
# 16        697.32       708.32
# 17        712.32       710.32
# 18        575.32       624.32
# 19        653.32       376.32
# 20        644.32       614.32
# 21        544.32       763.32
# 22        771.32       772.32
# 23        421.32       499.32
# 24        737.32       761.32
# 25        652.32       697.32
# 26        636.32       515.32
# 27        521.32       548.32
# 28        437.32       369.32
# 29        508.32       515.32
# ..           ...          ...
# 239       185.32       341.32
# 240       635.32       652.32
# 241       643.32       659.32
# 242       319.32       318.32
# 243       431.32       675.32
# 244       125.32       152.32
# 245        67.32       164.32
# 246       341.32       342.32
# 247       384.32       373.32
# 248       104.32       226.32
# 249       157.32       314.32
# 250       276.32       355.32
# 251       569.32       565.32
# 252        98.32        96.32
# 253       254.32       221.32
# 254        95.32       180.32
# 255       218.32        81.32
# 256        86.32        82.32
# 257       239.32       355.32
# 258       171.32       184.32
# 259       455.32       418.32
# 260       140.32        97.32
# 261       327.32       333.32
# 262       115.32       111.32
# 263       196.32       239.32
# 264       119.32       207.32
# 265       563.32       565.32
# 266        86.32        90.32
# 267       102.32       118.32
# 268       263.32       249.32
#
# [269 rows x 7 columns]

# %% [markdown]
# Vizualizacija svih centaršuteva za Mgladbach

# %%
dfx1Doma = dframe_BM_FL_248['actionPosX1']
dfy1Doma = dframe_BM_FL_248['actionPosY1']
dfx2Doma = dframe_BM_FL_248['actionPosX2']
dfy2Doma = dframe_BM_FL_248['actionPosY2']


dfx1Doma = dframe_EF_FL_248['actionPosX1']
dfy1Doma = dframe_EF_FL_248['actionPosY1']
dfx2Doma = dframe_EF_FL_248['actionPosX2']
dfy2Doma = dframe_EF_FL_248['actionPosY2']
#dfx1Gosti = dfGosti['actionPosX1']
#dfy1Gosti = dfGosti['actionPosY1']
#dfx2Gosti = dfGosti['actionPosX2']
#dfy2Gosti = dfGosti['actionPosY2']

fig = plt.figure(figsize = (12, 24))
fig.clf()
ax1 = fig.add_subplot(1,1,1)
ax2 = fig.add_subplot(1,1,1)
ax3 = fig.add_subplot(1,1,1)
ax4 = fig.add_subplot(1,1,1)

plt.plot([dfx1Doma, dfx2Doma], [dfy1Doma, dfy2Doma], c='black')
#plt.plot([dfx1Gosti, dfx2Gosti], [dfy1Gosti, dfy2Gosti], c='black')
plt.yticks([0,225,450,675,900])
plt.xticks([0,350,700,1050,1400])
im = plt.imread('igraliste2.png')
ax1.scatter(dfx1Doma, dfy1Doma, s=60, zorder=1, c='b', label='Početak doma')
ax2.scatter(dfx2Doma, dfy2Doma, s=60, zorder=1, c='y', label='Kraj doma')
#ax3.scatter(dfx1Gosti, dfy1Gosti, s=60, zorder=1, c='r', label='Početak gosti')
#ax4.scatter(dfx2Gosti, dfy2Gosti, s=60, zorder=1, c='c', label='Kraj gosti')

implot = plt.imshow(im, zorder=0, extent=[0, 1400, 900, 0])
plt.xlabel('actionPosX')
plt.ylabel('actionPosY')
plt.title('Lokacije početka i kraja centaršutova prema koordinatama - Mgladbach ukupno')

plt.legend(loc='upper center')
plt.show()
