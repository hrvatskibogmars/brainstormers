# %%
import numpy as np
import seaborn as sns
import pandas as pd
from pandas import Series,DataFrame
import os

#Dohvacanje CSV datoteke za utakmice 
fileDirU = os.path.dirname(os.path.realpath('mozgalo_gladbach_eintracht_utakmice.csv'))
filenameU = os.path.join(fileDirU, '../../data/clean/mozgalo_gladbach_eintracht_utakmice.csv')
fileU = os.path.abspath(os.path.realpath(filenameU))

#Dohvacanje CSV datoteke za akcije
fileDirA = os.path.dirname(os.path.realpath('mozgalo_gladbach_eintracht_akcije.csv'))
filenameA = os.path.join(fileDirA, '../../data/new_attributes/mozgalo_gladbach_eintracht_akcije.csv')
fileA = os.path.abspath(os.path.realpath(filenameA))

#Dohvacanje XLSX datoteke za akcije
fileDirC = os.path.dirname(os.path.realpath('Once - Lista akcija.xlsx'))
filenameC = os.path.join(fileDirA, '../../data/clean/Once - Lista akcija.xlsx')
fileC = os.path.abspath(os.path.realpath(filenameC))

#Dohvacanje XLSX datoteke za pozicije igrača
fileDirD = os.path.dirname(os.path.realpath('once_player_position.xlsx'))
filenameD = os.path.join(fileDirD, '../../data/clean/once_player_position.xlsx')
fileD = os.path.abspath(os.path.realpath(filenameD))

#Dohvacanje XLSX datoteke za pozicije igrača
fileDirEF = os.path.dirname(os.path.realpath('eintrachtFrankfurtSveAkcije.xls'))
filenameEF = os.path.join(fileDirEF, '../Hrvoje/EF/eintrachtFrankfurtSveAkcije.xls')
fileEF = os.path.abspath(os.path.realpath(filenameEF))

# %%
dframe_akcije = pd.read_csv(fileA)
dframe_utakmice = pd.read_csv(fileU)
dframe_ef = pd.read_excel(fileEF)

# %%
zamjene = dframe_akcije.loc[dframe_akcije["actionID"] == 212]

# %%
zamjene.reset_index(inplace=True,drop=True)

# %%
zamjene.sort_values("gameID")
# Out:
#           ID  gameID  actionStartTime  actionEndTime  actionID  \
# 0    6262495    6258          3555.30        3555.30       212
# 1    6263119    6258          3908.16        3908.16       212
# 2    6264230    6258          4692.47        4692.47       212
# 3    6265027    6258          5296.76        5296.76       212
# 5    6265360    6258          5569.17        5569.17       212
# 4    6265283    6261          3029.56        3029.56       212
# 6    6267405    6261          3977.51        3977.51       212
# 7    6268415    6261          4575.37        4575.37       212
# 8    6268512    6261          4687.26        4687.26       212
# 9    6269034    6261          5225.27        5225.27       212
# 10   6269101    6261          5449.84        5449.84       212
# 21   6316990    6307          5455.15        5455.15       212
# 20   6316901    6307          5400.69        5400.69       212
# 18   6316465    6307          5084.89        5084.89       212
# 15   6315768    6307          4672.94        4672.94       212
# 19   6316695    6307          5271.60        5271.60       212
# 14   6315567    6307          4553.58        4553.58       212
# 16   6316096    6308          4578.46        4578.46       212
# 17   6316454    6308          4790.41        4790.41       212
# 13   6314753    6308          3850.54        3850.54       212
# 12   6314234    6308          3684.46        3684.46       212
# 11   6308116    6308          1297.39        1297.39       212
# 22   6317262    6308          5287.87        5287.87       212
# 28   6347673    6347          5182.20        5182.20       212
# 26   6347480    6347          4717.60        4717.60       212
# 27   6347598    6347          4924.92        4924.92       212
# 24   6346841    6347          3817.36        3817.36       212
# 23   6344566    6347           774.20         774.20       212
# 161               0               0    185121            0       away
# 160               0               0    175582            0       away
# 158               0               0    101192            0       away
# 157               0               0     38434            0       home
# 159               0               0     54495            0       home
# 166               0               0     40700            0       home
# 163               0               0    206101            0       home
# 164               0               0      9795            0       away
# 165               0               0     47090            0       away
# 167               0               0     56086            0       away
#
#         ...      endPossTime  gameTimeSection  playerPositionID  \
# 0       ...                0       SecondHalf                16
# 1       ...                0       SecondHalf                17
# 2       ...                0       SecondHalf                18
# 3       ...                0       SecondHalf                11
# 5       ...                0       SecondHalf                21
# 4       ...                0       SecondHalf                12
# 6       ...                0       SecondHalf                12
# 7       ...                0       SecondHalf                12
# 8       ...                0       SecondHalf                12
# 9       ...                0       SecondHalf                12
# 10      ...                0       SecondHalf                12
# 21      ...                0       SecondHalf                16
# 20      ...                0       SecondHalf                 2
# 18      ...                0       SecondHalf                15
# 15      ...                0       SecondHalf                13
# 19      ...                0       SecondHalf                21
# 14      ...                0       SecondHalf                21
# 16      ...                0       SecondHalf                 4
# 17      ...                0       SecondHalf                 9
# 13      ...                0       SecondHalf                20
# 12      ...                0       SecondHalf                11
# 11      ...                0        FirstHalf                11
# 22      ...                0       SecondHalf                21
# 28      ...                0       SecondHalf                20
# 26      ...                0       SecondHalf                16
# 27      ...                0       SecondHalf                 4
# 24      ...                0       SecondHalf                16
# 23      ...                0        FirstHalf                21
# 25      ...                0       SecondHalf                11
# 29      ...                0       SecondHalf                16
# ..      ...              ...              ...               ...
# 135     ...                0       SecondHalf                16
# 134     ...                0       SecondHalf                16
# 140     ...                0       SecondHalf                21
# 141     ...                0       SecondHalf                 9
# 142     ...                0       SecondHalf                14
# 143     ...                0       SecondHalf                11
# 144     ...                0       SecondHalf                15
# 145     ...                0       SecondHalf                16
# 153     ...                0       SecondHalf                27
# 150     ...                0       SecondHalf                16
# 149     ...                0       SecondHalf                15
# 146     ...                0        FirstHalf                20
# 147     ...                0       SecondHalf                11
# 148     ...                0       SecondHalf                16
# 151     ...                0       SecondHalf                20
# 152     ...                0       SecondHalf                20
# 154     ...                0       SecondHalf                15
# 155     ...                0       SecondHalf                16
# 156     ...                0       SecondHalf                17
# 162     ...                0       SecondHalf                17
# 161     ...                0       SecondHalf                21
# 160     ...                0       SecondHalf                 9
# 158     ...                0       SecondHalf                16
# 157     ...                0       SecondHalf                23
# 159     ...                0       SecondHalf                 9
# 166     ...                0       SecondHalf                14
# 163     ...                0       SecondHalf                15
# 164     ...                0       SecondHalf                15
# 165     ...                0       SecondHalf                11
# 167     ...                0       SecondHalf                 8
#
#      targetPositionID  awayTeamSide action_duration  poss_duration  \
# 0                  16         right               0              0
# 1                  17         right               0              0
# 2                  18         right               0              0
# 3                  11         right               0              0
# 5                  21         right               0              0
# 4                  16          left               0              0
# 6                  16          left               0              0
# 7                  11          left               0              0
# 8                  21          left               0              0
# 9                  18          left               0              0
# 10                 21          left               0              0
# 21                 16          left               0              0
# 20                  2          left               0              0
# 18                 15          left               0              0
# 15                 13          left               0              0
# 19                 21          left               0              0
# 14                 21          left               0              0
# 16                  4         right               0              0
# 17                  9         right               0              0
# 173      LCM          70           0   29   0      ...        0   0   0   0
# 174      RWB           0         128   46   1      ...        0   0   0   0
# 175       CM           0         102   30   2      ...        0   0   0   0
# 176      LCB           0         157   65   2      ...        0   0   0   0
# 177      RCF           0         104   21   0      ...        0   0   0   0
# 178      CAM           0         150   46   4      ...        0   0   0   0
# 179      RCB           0          75   22   2      ...        0   0   0   0
# 180      RCB           0          30   16   0      ...        0   0   0   0
# 181       GK          23         120   24   0      ...        0   0   0   0
# 182      LCF           0         142   45   4      ...        0   0   0   0
# 183      LCM           0          59   14   4      ...        0   0   0   0
# 184      LCM           0          58    8   1      ...        0   0   0   0
# 185      RCM           0          79   30   1      ...        0   0   0   0
# 186      LWB           0         139   50   2      ...        0   0   0   0
#
#      91  99  16  163  matchStatus  possDuration
# 0     0   0   0    0            d        217.60
# 1     0   0   0    0            d        139.70
# 2     0   0   0    0            d        266.51
# 3     0   0   0    0            d        127.97
# 4     0   0   0    0            d          5.46
# 5     0   0   0    0            d         95.79
# 6     0   0   0    0            d          0.00
# 7     0   0   0    0            d        150.64
# 8     0   0   0    0            d        163.43
# 9     0   0   0    0            d        126.50
# 10    0   0   0    0            d        152.93
# 11    0   0   0    0            d         51.32
# 12    0   0   0    0            d        103.50
# 13    0   0   0    0            l        162.58
# 14    0   0   0    0            l         63.40
# 15    0   0   0    0            l        118.19
# 16    0   0   0    0            l         36.50
# 17    0   0   0    0            l        102.38
# 18    0   0   0    0            l         21.38
# 19    0   0   0    0            l         36.80
# 20    0   0   0    0            l        143.74
# 21    0   0   0    0            l         21.34
# 22    0   0   0    0            l        114.35
# 23    0   0   0    0            l         18.01
# 24    0   0   0    0            l         20.43
# 25    0   0   0    0            l        155.86
# 26    0   0   0    0            l        131.05
# 27    0   0   0    0            l         66.75
# 28    0   0   0    0            l         91.37
# 29    0   0   0    0            l        125.53
# ..   ..  ..  ..  ...          ...           ...
# 157   0   0   0    0            d        106.80
# 158   0   0   0    0            d        121.85
# 159   0   0   0    0            d         22.00
# 160   0   0   0    0            d          0.00
# 161   0   0   0    0            l         68.96
# 162   0   0   0    0            l         96.60
# 163   0   0   0    0            l        104.21
# 164   0   0   0    0            l         86.47
# 165   0   0   0    0            l         60.73
# 166   0   0   0    0            l         80.43
# 167   0   0   0    0            l        283.81
# 168   0   0   0    0            l        102.71
# 169   0   0   0    0            l         31.70
# 170   0   0   0    0            l         45.22
# 171   0   0   0    0            l         73.19
# 172   0   0   0    0            l          6.03
# 173   0   0   0    0            l         57.99
# 174   0   0   0    0            d        101.94
# 175   0   0   0    0            d         57.63
# 176   0   0   0    0            d        109.60
# 177   0   0   0    0            d         67.40
# 178   0   0   0    0            d        121.50
# 179   0   0   0    0            d         53.25
# 180   0   0   0    0            d         22.11
# 181   2   0   0    1            d        209.79
# 182   0   0   0    0            d        200.48
# 183   0   0   0    0            d         36.61
# 184   0   0   0    0            d         60.79
# 185   0   0   0    0            d         82.43
# 186   0   0   0    0            d        123.83
#
# [187 rows x 78 columns]

# %%
for indexA,itemA in zamjene.iterrows():
    for indexB,itemB in dframe_ef.iterrows():
        if(itemA["playerID"] == itemB["playerID"] and itemA["gameID"] == itemB["gameID"]):
            if (itemA["gameTimeSection"] == "FirstHalf"):
                #dohvatiti zadnje vrijeme prvog poluvremena
                #spremiti trenutni broj minuta za igrača koji izlazi iz igre
                #za igrača koji ulazi izračunati razliku između završetka igre i vrijme ulaska
                
                pomFH = pd.DataFrame()
                pomFH = dframe_akcije.loc[(dframe_akcije["gameID"] == itemA.gameID) & (dframe_akcije["gameTimeSection"] == "FirstHalf")]
                pomMaxFH = pomFH.loc[pomFH["actionStartTime"].idxmax()]
                
                #Vrijeme zamjene
                print ("Igrac koji izlazi: " + str(itemA["playerID"]))
                print ("Vrijeme izlaska: " + str(round(itemA.actionStartTime)))
                
                #Završetak prvog poluvremena
                print ("Igrac koji uzlazi: "  + str(itemA["targetPlayerID"]))
                print ("Završetak FH " + str(pomMaxFH.actionStartTime))
                print ("Na terenu povodi "+ str(pomMaxFH.actionStartTime - itemA.actionStartTime))       
                
                #Vrijeme trajanja drugog poluvremena
                pomSH = pd.DataFrame()
                pomSH = dframe_akcije.loc[dframe_akcije["gameID"] == itemA.gameID]
                pomMaxSH = pomSH.loc[pomSH["actionStartTime"].idxmax()]
                
                #Izacun ukupnog vremena provedenog u igri
                #pomMaxFH.actionStartTime - kraj prvog poluvremena
                #itemA.actionStartTime - vrijeme zamjene
                #pomMaxSH.actionStartTime - 2700 = Kraj drugog poluvremena - 2700 (početak prvog)
                izracun = 0
                izracun = (pomMaxFH.actionStartTime - itemA.actionStartTime) + (pomMaxSH.actionStartTime - 2700)
                
                
                print ("Na terenu povodi ukupno "+ str(izracun/60))
                
            if (itemA["gameTimeSection"] == "SecondHalf"):
                print (itemA.gameID)
                
                pomSH = pd.DataFrame()
                pomSH = dframe_akcije.loc[dframe_akcije["gameID"] == itemA.gameID]
                pomMaxSH = pomSH.loc[pomSH["actionStartTime"].idxmax()]
                
                #Vrijeme zamjene
                print ("Igrac koji izlazi: " + str(itemA["playerID"]))
                print ("Vrijeme izlaska: " + str(itemA.actionStartTime))
                
                #Završetak prvog poluvremena
                print ("Igrac koji uzlazi: "  + str(itemA["targetPlayerID"]))
                print ("Završetak SH " + str(pomMaxSH.actionStartTime))
                print ("Na terenu povodi "+ str(pomMaxSH.actionStartTime - itemA.actionStartTime))
                
                izracun = 0
                izracun = (pomMaxSH.actionStartTime - itemA.actionStartTime)
                
                print ("Na terenu povodi ukupno "+ str(izracun/60))

                print ()
# Out:
# 6258
# Igrac koji izlazi: 102895
# Vrijeme izlaska: 5296.76
# Igrac koji uzlazi: 77888
# Završetak SH 5576.06
# Na terenu povodi 279.3
# Na terenu povodi ukupno 4.655
#
# 6258
# Igrac koji izlazi: 205986
# Vrijeme izlaska: 5569.17
# Igrac koji uzlazi: 16520
# Završetak SH 5576.06
# Na terenu povodi 6.89
# Na terenu povodi ukupno 0.114833333333
#
# Igrac koji izlazi: 57720
# Vrijeme izlaska: 1297
# Igrac koji uzlazi: 102895
# Završetak FH 2703.08
# Na terenu povodi 1405.69
# Na terenu povodi ukupno 71.2286666667
# 6308
# Igrac koji izlazi: 206102
# Vrijeme izlaska: 3850.54
# Igrac koji uzlazi: 196661
# Završetak SH 5568.03
# Na terenu povodi 1717.49
# Na terenu povodi ukupno 28.6248333333
#
# 6308
# Igrac koji izlazi: 206101
# Vrijeme izlaska: 4578.46
# Igrac koji uzlazi: 5335
# Završetak SH 5568.03
# Na terenu povodi 989.57
# Na terenu povodi ukupno 16.4928333333
#
# 6370
# Igrac koji izlazi: 67519
# Vrijeme izlaska: 4998.56
# Igrac koji uzlazi: 5335
# Završetak SH 5640.47
# Na terenu povodi 641.91
# Na terenu povodi ukupno 10.6985
#
# Igrac koji izlazi: 1790
# Vrijeme izlaska: 2068
# Igrac koji uzlazi: 21022
# Završetak FH 2666.87
# Na terenu povodi 598.77
# Na terenu povodi ukupno 59.7405
# 6398
# Igrac koji izlazi: 206101
# Vrijeme izlaska: 2699.14
# Igrac koji uzlazi: 203576
# Završetak SH 5685.66
# Na terenu povodi 2986.52
# Na terenu povodi ukupno 49.7753333333
#
# 6398
# Igrac koji izlazi: 67519
# Vrijeme izlaska: 4777.55
# Igrac koji uzlazi: 40700
# Završetak SH 5685.66
# Na terenu povodi 908.11
# Na terenu povodi ukupno 15.1351666667
#
# 6425
# Igrac koji izlazi: 57720
# Vrijeme izlaska: 2700.0
# Igrac koji uzlazi: 16520
# Završetak SH 5402.0
# Na terenu povodi 2702.0
# Na terenu povodi ukupno 45.0333333333
#
# 6425
# Igrac koji izlazi: 214449
# Vrijeme izlaska: 5063.3
# Igrac koji uzlazi: 21022
# Završetak SH 5402.0
# Na terenu povodi 338.7
# Na terenu povodi ukupno 5.645
#
# Igrac koji izlazi: 203576
# Vrijeme izlaska: 2103
# Igrac koji uzlazi: 67519
# Završetak FH 2699.82
# Na terenu povodi 596.59
# Na terenu povodi ukupno 57.7923333333
# 6450
# Igrac koji izlazi: 12956
# Vrijeme izlaska: 5344.59
# Igrac koji uzlazi: 203576
# Završetak SH 5570.95
# Na terenu povodi 226.36
# Na terenu povodi ukupno 3.77266666667
#
# 6553
# Igrac koji izlazi: 22870
# Vrijeme izlaska: 2700.0
# Igrac koji uzlazi: 77888
# Završetak SH 5591.63
# Na terenu povodi 2891.63
# Na terenu povodi ukupno 48.1938333333
#
# 6553
# Igrac koji izlazi: 196661
# Vrijeme izlaska: 5489.27
# Igrac koji uzlazi: 16520
# Završetak SH 5591.63
# Na terenu povodi 102.36
# Na terenu povodi ukupno 1.706
#
# 6573
# Igrac koji izlazi: 196661
# Vrijeme izlaska: 5284.47
# Igrac koji uzlazi: 22870
# Završetak SH 5516.31
# Na terenu povodi 231.84
# Na terenu povodi ukupno 3.864
#
# 6573
# Igrac koji izlazi: 77888
# Vrijeme izlaska: 5399.43
# Igrac koji uzlazi: 16520
# Završetak SH 5516.31
# Na terenu povodi 116.88
# Na terenu povodi ukupno 1.948
#
# 6609
# Igrac koji izlazi: 7466
# Vrijeme izlaska: 2700.0
# Igrac koji uzlazi: 201624
# Završetak SH 5576.56
# Na terenu povodi 2876.56
# Na terenu povodi ukupno 47.9426666667
#
# 6609
# Igrac koji izlazi: 203576
# Vrijeme izlaska: 4357.37
# Igrac koji uzlazi: 212914
# Završetak SH 5576.56
# Na terenu povodi 1219.19
# Na terenu povodi ukupno 20.3198333333
#
# 6609
# Igrac koji izlazi: 40700
# Vrijeme izlaska: 4672.88
# Igrac koji uzlazi: 16520
# Završetak SH 5576.56
# Na terenu povodi 903.68
# Na terenu povodi ukupno 15.0613333333
#
# 6647
# Igrac koji izlazi: 77888
# Vrijeme izlaska: 3582.2
# Igrac koji uzlazi: 5335
# Završetak SH 5592.69
# Na terenu povodi 2010.49
# Na terenu povodi ukupno 33.5081666667
#
# 6647
# Igrac koji izlazi: 7466
# Vrijeme izlaska: 4374.76
# Igrac koji uzlazi: 22870
# Završetak SH 5592.69
# Na terenu povodi 1217.93
# Na terenu povodi ukupno 20.2988333333
#
# 6681
# Igrac koji izlazi: 77888
# Vrijeme izlaska: 2700.0
# Igrac koji uzlazi: 1770
# Završetak SH 5516.78
# Na terenu povodi 2816.78
# Na terenu povodi ukupno 46.9463333333
#
# 6681
# Igrac koji izlazi: 40700
# Vrijeme izlaska: 4858.45
# Igrac koji uzlazi: 199745
# Završetak SH 5516.78
# Na terenu povodi 658.33
# Na terenu povodi ukupno 10.9721666667
#
# 6681
# Igrac koji izlazi: 203576
# Vrijeme izlaska: 5364.84
# Igrac koji uzlazi: 16520
# Završetak SH 5516.78
# Na terenu povodi 151.94
# Na terenu povodi ukupno 2.53233333333
#
# 6730
# Igrac koji izlazi: 212914
# Vrijeme izlaska: 4236.22
# Igrac koji uzlazi: 39442
# Završetak SH 5462.39
# Na terenu povodi 1226.17
# Na terenu povodi ukupno 20.4361666667
#
# 6730
# Igrac koji izlazi: 143853
# Vrijeme izlaska: 5184.48
# Igrac koji uzlazi: 1770
# Završetak SH 5462.39
# Na terenu povodi 277.91
# Na terenu povodi ukupno 4.63183333333
#
# 6730
# Igrac koji izlazi: 143853
# Vrijeme izlaska: 5184.48
# Igrac koji uzlazi: 1770
# Završetak SH 5462.39
# Na terenu povodi 277.91
# Na terenu povodi ukupno 4.63183333333
#
# 6730
# Igrac koji izlazi: 40700
# Vrijeme izlaska: 5218.11
# Igrac koji uzlazi: 199745
# Završetak SH 5462.39
# Na terenu povodi 244.28
# Na terenu povodi ukupno 4.07133333333
#
# 6756
# Igrac koji izlazi: 143853
# Vrijeme izlaska: 4202.91
# Igrac koji uzlazi: 1770
# Završetak SH 5571.39
# Na terenu povodi 1368.48
# Na terenu povodi ukupno 22.808
#
# 6756
# Igrac koji izlazi: 206101
# Vrijeme izlaska: 4699.65
# Igrac koji uzlazi: 199745
# Završetak SH 5571.39
# Na terenu povodi 871.74
# Na terenu povodi ukupno 14.529
#
# 6770
# Igrac koji izlazi: 206101
# Vrijeme izlaska: 2700.0
# Igrac koji uzlazi: 199745
# Završetak SH 5610.15
# Na terenu povodi 2910.15
# Na terenu povodi ukupno 48.5025
#
# 6770
# Igrac koji izlazi: 40700
# Vrijeme izlaska: 4164.86
# Igrac koji uzlazi: 39442
# Završetak SH 5610.15
# Na terenu povodi 1445.29
# Na terenu povodi ukupno 24.0881666667
