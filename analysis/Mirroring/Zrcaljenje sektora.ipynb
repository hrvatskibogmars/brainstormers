# %%
import numpy as np
import seaborn as sns
import pandas as pd
from pandas import Series,DataFrame
import os
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

#Dohvacanje CSV datoteke za utakmice 
fileDirU = os.path.dirname(os.path.realpath('mozgalo_gladbach_eintracht_utakmice.csv'))
filenameU = os.path.join(fileDirU, '../../data/clean/mozgalo_gladbach_eintracht_utakmice.csv')
fileU = os.path.abspath(os.path.realpath(filenameU))

#Dohvacanje CSV datoteke za akcije
fileDirA = os.path.dirname(os.path.realpath('mozgalo_gladbach_eintracht_akcije.csv'))
filenameA = os.path.join(fileDirA, '../../data/new_attributes/mozgalo_gladbach_eintracht_akcije.csv')
fileA = os.path.abspath(os.path.realpath(filenameA))

#Dohvacanje XLSX datoteke za akcije
fileDirC = os.path.dirname(os.path.realpath('Once - Lista akcija.xlsx'))
filenameC = os.path.join(fileDirA, '../../data/clean/Once - Lista akcija.xlsx')
fileC = os.path.abspath(os.path.realpath(filenameC))

#Dohvacanje XLSX datoteke za pozicije igrača
fileDirD = os.path.dirname(os.path.realpath('once_player_position.xlsx'))
filenameD = os.path.join(fileDirD, '../../data/clean/once_player_position.xlsx')
fileD = os.path.abspath(os.path.realpath(filenameD))

# %%
#dframe_akcije = pd.read_csv(fileA)
dframe_utakmice = pd.read_csv(fileU)
dframe_efAkcije = pd.read_csv("Eintracht_ukupneAkcije.csv")

dframe_eintrachtFrankfurt = pd.read_excel("efPlayers.xls")
dframe_borussiaMgladbach = pd.read_excel("bmPlayers.xls")

# %%
dframe_efAkcije.columns
# Out:
# Index(['ID', 'gameID', 'actionStartTime', 'actionEndTime', 'actionID',
#        'bindedActionID', 'actionOptionID', 'playerID', 'actionIDNaziv',
#        'bindedActionIDN', 'actionOptionIDN', 'targetPlayerID',
#        'playerPositionIDN', 'targetPositionIDN', 'touchNumber', 'playerTeam',
#        'actionPosX1', 'actionPosX2', 'actionPosY1', 'actionPosY2', 'goalZone',
#        'distance', 'refPositionX', 'refPositionY', 'startPossTime',
#        'endPossTime', 'gameTimeSection', 'playerPositionID',
#        'targetPositionID', 'awayTeamSide', 'action_duration', 'poss_duration',
#        'start_sector', 'end_sector', 'ref_sector', 'domaci', 'gosti',
#        'domaciFormacija', 'gostiFormacija', 'gameDate', 'gameTime', 'stadium',
#        'referee', 'climate', 'luna', 'temperature', 'viewers', 'domaciID',
#        'gostiID', 'homeTeamFormacijaID', 'awayTeamFormacijaID',
#        'Pogodaka_domaci', 'Score_domaci', 'Pogodaka_gosti', 'Score_gosti'],
#       dtype='object')

# %%
for indexA, itemA in dframe_efAkcije.iterrows():
    if((itemA["gameTimeSection"] == "FirstHalf" and itemA["awayTeamSide"] == "right" and itemA["domaci"]=="Borussia Mgladbach") or
       (itemA["gameTimeSection"] == "SecondHalf" and itemA["awayTeamSide"] == "right" and itemA["domaci"]=="Borussia Mgladbach") or 
       (itemA["gameTimeSection"] == "FirstHalf" and itemA["awayTeamSide"] == "left" and itemA["gosti"]=="Borussia Mgladbach")):
        
        if (itemA["start_sector"] == 1):
            dframe_efAkcije.loc[indexA, "start_sector"] = 16
        if (itemA["start_sector"] == 2):
            dframe_efAkcije.loc[indexA, "start_sector"] = 15
        if (itemA["start_sector"] == 5):
            dframe_efAkcije.loc[indexA, "start_sector"] = 12
        if (itemA["start_sector"] == 6):
            dframe_efAkcije.loc[indexA, "start_sector"] = 11
        if (itemA["start_sector"] == 9):
            dframe_efAkcije.loc[indexA, "start_sector"] = 8
        if (itemA["start_sector"] == 10):
            dframe_efAkcije.loc[indexA, "start_sector"] = 7
        if (itemA["start_sector"] == 13):
            dframe_efAkcije.loc[indexA, "start_sector"] = 4
        if (itemA["start_sector"] == 14):
            dframe_efAkcije.loc[indexA, "start_sector"] = 3
            
        if (itemA["start_sector"] == 16):
            dframe_efAkcije.loc[indexA, "start_sector"] = 1
        if (itemA["start_sector"] == 15):
            dframe_efAkcije.loc[indexA, "start_sector"] = 2
        if (itemA["start_sector"] == 12):
            dframe_efAkcije.loc[indexA, "start_sector"] = 5
        if (itemA["start_sector"] == 11):
            dframe_efAkcije.loc[indexA, "start_sector"] = 6
        if (itemA["start_sector"] == 8):
            dframe_efAkcije.loc[indexA, "start_sector"] = 9
        if (itemA["start_sector"] == 7):
            dframe_efAkcije.loc[indexA, "start_sector"] = 10
        if (itemA["start_sector"] == 4):
            dframe_efAkcije.loc[indexA, "start_sector"] = 13
        if (itemA["start_sector"] == 3):
            dframe_efAkcije.loc[indexA, "start_sector"] = 14
        
        if (itemA["end_sector"] == 1):
            dframe_efAkcije.loc[indexA, "end_sector"] = 16
        if (itemA["end_sector"] == 2):
            dframe_efAkcije.loc[indexA, "end_sector"] = 15
        if (itemA["end_sector"] == 5):
            dframe_efAkcije.loc[indexA, "end_sector"] = 12
        if (itemA["end_sector"] == 6):
            dframe_efAkcije.loc[indexA, "end_sector"] = 11
        if (itemA["end_sector"] == 9):
            dframe_efAkcije.loc[indexA, "end_sector"] = 8
        if (itemA["end_sector"] == 10):
            dframe_efAkcije.loc[indexA, "end_sector"] = 7
        if (itemA["end_sector"] == 13):
            dframe_efAkcije.loc[indexA, "end_sector"] = 4
        if (itemA["end_sector"] == 14):
            dframe_efAkcije.loc[indexA, "end_sector"] = 3
            
        if (itemA["end_sector"] == 16):
            dframe_efAkcije.loc[indexA, "end_sector"] = 1
        if (itemA["end_sector"] == 15):
            dframe_efAkcije.loc[indexA, "end_sector"] = 2
        if (itemA["end_sector"] == 12):
            dframe_efAkcije.loc[indexA, "end_sector"] = 5
        if (itemA["end_sector"] == 11):
            dframe_efAkcije.loc[indexA, "end_sector"] = 6
        if (itemA["end_sector"] == 8):
            dframe_efAkcije.loc[indexA, "end_sector"] = 9
        if (itemA["end_sector"] == 7):
            dframe_efAkcije.loc[indexA, "end_sector"] = 10
        if (itemA["end_sector"] == 4):
            dframe_efAkcije.loc[indexA, "end_sector"] = 13
        if (itemA["end_sector"] == 3):
            dframe_efAkcije.loc[indexA, "end_sector"] = 14

# %%
#dframe_FL_247 = pd.DataFrame(columns=['ID','playerID','targetPlayerID','actionPosX1', 'actionPosX2', 'actionPosY1','actionPosY2','start_sector',"end_sector"])
#dframe_SR_247 = pd.DataFrame(columns=['ID','playerID','targetPlayerID','actionPosX1', 'actionPosX2', 'actionPosY1','actionPosY2','start_sector',"end_sector"]) 
dframe_graph = pd.DataFrame(columns=['ID','playerID','targetPlayerID','actionPosX1', 'actionPosX2', 'actionPosY1','actionPosY2',
                                     'start_sector',"end_sector","playerPositionIDN","targetPositionIDN"])
for indexB, itemB in dframe_efAkcije.iterrows():
    #if(itemB["gameTimeSection"] == "FirstHalf"):
    if (itemB["actionID"] == 247):
        dframe_graph.loc[len(dframe_graph)] = itemB
            
    #if(itemB["gameTimeSection"] == "SecondHalf"):
       # if (itemB["actionID"] == 1):
            #dframe_SR_247.loc[len(dframe_SR_247)] = item

# %%
dframe_graph
# Out:
#            ID  playerID  targetPlayerID  actionPosX1  actionPosX2  \
# 0     6257045    196633           21022          618          384
# 1     6257046     21022           44079          380          376
# 2     6257047     44079           21022          383          455
# 3     6257048     21022          196633          478          531
# 4     6257049    196633          196661          628          734
# 5     6257050    196661          196633          746          705
# 6     6257058    199745           21022          476          420
# 7     6257061     21022            5335          417          400
# 8     6257062      5335           16520          426          545
# 9     6257063     16520           77888          684          872
# 10    6257064     77888          199745          885          682
# 11    6257080     77888            1802          773          725
# 12    6257082      1802           16520          712          687
# ...

# %%
#dframe_efAkcije.to_csv("mirroringBMSektori.csv",index=False)

# %%
dframe_ef_parovi =dframe_graph[["playerID","targetPlayerID","playerPositionIDN","targetPositionIDN"]]
dframe_ef_parovi
# Out:
#       playerID  targetPlayerID playerPositionIDN targetPositionIDN
# 0       196633           21022                LB               LCB
# 1        21022           44079               LCB               LCM
# 2        44079           21022               LCM               LCB
# 3        21022          196633               LCB                LB
# 4       196633          196661                LB                LW
# 5       196661          196633                LW                LB
# 6       199745           21022               RCM               LCB
# 7        21022            5335               LCB                RB
# 8         5335           16520                RB                RW
# 9        16520           77888                RW                ST
# 10       77888          199745                ST               RCM
# 11       77888            1802                ST               CAM
# 12        1802           16520               CAM                RW
# ...

# %%
dframe_ef_parovi.drop_duplicates(inplace=True)
dframe_ef_parovi.reset_index(inplace=True,drop=True)
dframe_ef_parovi
dframe_ef_parovi["ukupno"] = 0 

for indexA,itemA in dframe_ef_parovi.iterrows():
    for indexB,itemB in dframe_graph.iterrows():
        if(itemA["playerID"] == itemB["playerID"] and itemA["targetPlayerID"] == itemB["targetPlayerID"]):
            dframe_ef_parovi.ix[indexA,"ukupno"] +=1

# %%
dframe_ef_parovi

# %%
dframe_ef_parovi.sort_values("ukupno",ascending=False)
