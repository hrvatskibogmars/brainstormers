# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %%
dframe_utakmice = pd.read_csv("mozgalo_gladbach_eintracht_utakmice.csv", sep=",")

# %%
dframe_utakmice
# Out:
#       ID                   liga               domaci                gosti  \
# 0   6770             Bundesliga  Eintracht Frankfurt     FC Ingolstadt 04
# 1   6765             Bundesliga        VfL Wolfsburg   Borussia Mgladbach
# 2   6756             Bundesliga           Hertha BSC  Eintracht Frankfurt
# 3   6755             Bundesliga   Borussia Mgladbach        VfB Stuttgart
# 4   6730             Bundesliga  Eintracht Frankfurt        FC Schalke 04
# 5   6725             Bundesliga          FC Augsburg   Borussia Mgladbach
# 6   6685             Bundesliga   Borussia Mgladbach           1. FC Koln
# 7   6681             Bundesliga  Eintracht Frankfurt         Hamburger SV
# 8   6652             Bundesliga         Hamburger SV   Borussia Mgladbach
# 9   6647             Bundesliga           1. FC Koln  Eintracht Frankfurt
# 10  6609             Bundesliga  Eintracht Frankfurt        VfB Stuttgart
# 11  6603             Bundesliga   Borussia Mgladbach     SV Werder Bremen
# ...

# %%
dframe_utakmice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 0 to 29
# Data columns (total 23 columns):
# ID                     30 non-null int64
# liga                   30 non-null object
# domaci                 30 non-null object
# gosti                  30 non-null object
# domaciFormacija        30 non-null object
# gostiFormacija         30 non-null object
# gameDate               30 non-null object
# gameTime               30 non-null object
# stadium                30 non-null object
# referee                30 non-null int64
# climate                30 non-null object
# luna                   30 non-null object
# temperature            30 non-null int64
# viewers                30 non-null int64
# datum                  30 non-null object
# domaciID               30 non-null int64
# gostiID                30 non-null int64
# homeTeamFormacijaID    30 non-null int64
# awayTeamFormacijaID    30 non-null int64
# Pogodaka_domaci        30 non-null int64
# ...

# %%
momcadi = pd.unique(dframe_utakmice[['domaci','gosti']].values.ravel())

# %%
momcadi
# Out:
# array(['Eintracht Frankfurt', 'FC Ingolstadt 04', 'VfL Wolfsburg',
#        'Borussia Mgladbach', 'Hertha BSC', 'VfB Stuttgart',
#        'FC Schalke 04', 'FC Augsburg', '1. FC Koln', 'Hamburger SV',
#        'SV Werder Bremen', '1. FSV Mainz 05', 'Borussia Dortmund',
#        'SV Darmstadt 98', 'Bayer 04 Leverkusen', 'Manchester City',
#        'FC Bayern Munchen', 'TSG 1899 Hoffenheim', 'Sevilla CF',
#        'Hannover 96'], dtype=object)

# %%
momcadi_piv = momcadi.pivot()

# %%
dframe_akcije = pd.read_csv("mozgalo_gladbach_eintracht_akcije.csv", sep=",")

# %%
dframe_akcije
# Out:
#             ID  gameID  actionStartTime  actionEndTime  actionID  \
# 0      6256994    6258             0.00           0.75       247
# 1      6256995    6258             0.75           1.31       247
# 2      6256996    6258             1.31           4.37       247
# 3      6256997    6258             4.37           7.12       247
# 4      6256998    6258             7.12           9.80       247
# 5      6256999    6258             9.80          11.38       247
# 6      6257000    6258            11.38          12.18       247
# 7      6257001    6258            12.18          15.11       247
# 8      6257002    6258            15.11          16.00       247
# 9      6257003    6258            16.00          16.92       247
# 10     6257004    6258            16.92          21.39       247
# 11     6257005    6258            21.39          23.45       247
# 12     6257006    6258            23.45          30.66       247
# ...

# %%
merge = pd.merge(dframe_utakmice,dframe_akcije,left_on='ID',right_on='gameID')
